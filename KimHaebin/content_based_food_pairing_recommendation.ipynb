# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/vivino_data_241107.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3675 entries, 0 to 3674
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vintage_id               3675 non-null   int64
#  1   vintage_name             3675 non-null   object
#  2   vintage_year             3675 non-null   object
#  3   vintage_price            3675 non-null   int64
#  4   vintage_ratings_average  3675 non-null   float64
#  5   vintage_ratings_count    3675 non-null   int64
#  6   vintage_wine_id          3675 non-null   int64
#  7   vintage_wine_name        3675 non-null   object
#  8   vintage_winery           3674 non-null   object
#  9   vintage_country          3675 non-null   object
#  10  vintage_region           3675 non-null   object
#  11  vintage_wine_type_id     3675 non-null   int64
#  12  acidity                  3555 non-null   float64
#  13  fizziness                507 non-null    float64
#  14  intensity                3555 non-null   float64
#  15  sweetness                3048 non-null   float64
#  16  tannin                   2267 non-null   float64
#  17  flavor                   3672 non-null   object
#  18  varietal_name            3675 non-null   object
#  19  body_description         3675 non-null   object
#  20  acidity_description      3675 non-null   object
#  21  foods                    3675 non-null   object
# dtypes: float64(6), int64(5), object(11)
# memory usage: 631.8+ KB

# %%
df.shape
# Out:
# (3675, 22)

# %%
df['vintage_name'].nunique()
# Out:
# 2024

# %%
# 중복된 행 찾기
duplicates = df[df.duplicated()]
duplicates.sort_values(by='vintage_id', ascending=False)
# Out:
#       vintage_id                                       vintage_name  \
# 3303   176127589                            Nederburg Pinotage 2003
# 2853   176127589                            Nederburg Pinotage 2003
# 2353   176127589                            Nederburg Pinotage 2003
# 2653   176127589                            Nederburg Pinotage 2003
# 2553   176127589                            Nederburg Pinotage 2003
# ...          ...                                                ...
# 2326     1330034  Château Vieux Lartigue Saint-Émilion Grand Cru...
# 2351     1330034  Château Vieux Lartigue Saint-Émilion Grand Cru...
# 3026     1330034  Château Vieux Lartigue Saint-Émilion Grand Cru...
# 3376     1330034  Château Vieux Lartigue Saint-Émilion Grand Cru...
# 1575     1201853            Cloudy Bay Te Koko Sauvignon Blanc 2005
#
#      vintage_year  vintage_price  vintage_ratings_average  \
# 3303         2003          25013                      3.9
# 2853         2003          25013                      3.9
# 2353         2003          25013                      3.9
# 2653         2003          25013                      3.9
# 2553         2003          25013                      3.9
# ...           ...            ...                      ...
# 2326         2000          59083                      3.9
# 2351         2000          59083                      3.9
# 3026         2000          59083                      3.9
# 3376         2000          59083                      3.9
# 1575         2005          77627                      4.1
#
#       vintage_ratings_count  vintage_wine_id             vintage_wine_name  \
# 3303                   2999          9520778                 Pinotage 2003
# 2853                   2999          9520778                 Pinotage 2003
# 2353                   2999          9520778                 Pinotage 2003
# 2653                   2999          9520778                 Pinotage 2003
# 2553                   2999          9520778                 Pinotage 2003
# ...                     ...              ...                           ...
# 2326                   3124          1159416  Saint-Émilion Grand Cru 2000
# 2351                   3124          1159416  Saint-Émilion Grand Cru 2000
# 3026                   3124          1159416  Saint-Émilion Grand Cru 2000
# 3376                   3124          1159416  Saint-Émilion Grand Cru 2000
# 1575                     35          1126958  Te Koko Sauvignon Blanc 2005
#
#               vintage_winery vintage_country  ... acidity  fizziness  \
# 3303               Nederburg    South Africa  ...    3.00        NaN
# 2853               Nederburg    South Africa  ...    3.00        NaN
# 2353               Nederburg    South Africa  ...    3.00        NaN
# 2653               Nederburg    South Africa  ...    3.00        NaN
# 2553               Nederburg    South Africa  ...    3.00        NaN
# ...                      ...             ...  ...     ...        ...
# 2326  Château Vieux Lartigue          France  ...    3.49        NaN
# 2351  Château Vieux Lartigue          France  ...    3.49        NaN
# 3026  Château Vieux Lartigue          France  ...    3.49        NaN
# 3376  Château Vieux Lartigue          France  ...    3.49        NaN
# 1575              Cloudy Bay     New Zealand  ...    4.38        NaN
#
#       intensity  sweetness  tannin        flavor    varietal_name  \
# 3303       3.66       2.29    3.13           oak         Pinotage
# 2853       3.66       2.29    3.13           oak         Pinotage
# 2353       3.66       2.29    3.13           oak         Pinotage
# 2653       3.66       2.29    3.13           oak         Pinotage
# 2553       3.66       2.29    3.13           oak         Pinotage
# ...         ...        ...     ...           ...              ...
# 2326       4.07       1.42    3.56           oak    Saint-Émilion
# 2351       4.07       1.42    3.56           oak    Saint-Émilion
# 3026       4.07       1.42    3.56           oak    Saint-Émilion
# 3376       4.07       1.42    3.56           oak    Saint-Émilion
# 1575       2.75       1.56     NaN  citrus_fruit  Sauvignon Blanc
#
#      body_description acidity_description  \
# 3303      Full-bodied                High
# 2853      Full-bodied                High
# 2353      Full-bodied                High
# 2653      Full-bodied                High
# 2553      Full-bodied                High
# ...               ...                 ...
# 2326      Full-bodied              Medium
# 2351      Full-bodied              Medium
# 3026      Full-bodied              Medium
# 3376      Full-bodied              Medium
# 1575     Light-bodied                High
#
#                                                   foods
# 3303        ['Beef', 'Game (deer, venison)', 'Poultry']
# 2853        ['Beef', 'Game (deer, venison)', 'Poultry']
# 2353        ['Beef', 'Game (deer, venison)', 'Poultry']
# 2653        ['Beef', 'Game (deer, venison)', 'Poultry']
# 2553        ['Beef', 'Game (deer, venison)', 'Poultry']
# ...                                                 ...
# 2326  ['Beef', 'Lamb', 'Game (deer, venison)', 'Poul...
# 2351  ['Beef', 'Lamb', 'Game (deer, venison)', 'Poul...
# 3026  ['Beef', 'Lamb', 'Game (deer, venison)', 'Poul...
# 3376  ['Beef', 'Lamb', 'Game (deer, venison)', 'Poul...
# 1575  ['Shellfish', 'Vegetarian', "Goat's Milk Cheese"]
#
# [1651 rows x 22 columns]

# %%
duplicates['vintage_name'].nunique()
# Out:
# 26

# %%
df = df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (2024, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2024 entries, 0 to 2024
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vintage_id               2024 non-null   int64
#  1   vintage_name             2024 non-null   object
#  2   vintage_year             2024 non-null   object
#  3   vintage_price            2024 non-null   int64
#  4   vintage_ratings_average  2024 non-null   float64
#  5   vintage_ratings_count    2024 non-null   int64
#  6   vintage_wine_id          2024 non-null   int64
#  7   vintage_wine_name        2024 non-null   object
#  8   vintage_winery           2023 non-null   object
#  9   vintage_country          2024 non-null   object
#  10  vintage_region           2024 non-null   object
#  11  vintage_wine_type_id     2024 non-null   int64
#  12  acidity                  1970 non-null   float64
#  13  fizziness                111 non-null    float64
#  14  intensity                1970 non-null   float64
#  15  sweetness                1859 non-null   float64
#  16  tannin                   1409 non-null   float64
#  17  flavor                   2021 non-null   object
#  18  varietal_name            2024 non-null   object
#  19  body_description         2024 non-null   object
#  20  acidity_description      2024 non-null   object
#  21  foods                    2024 non-null   object
# dtypes: float64(6), int64(5), object(11)
# memory usage: 363.7+ KB

# %%
df['vintage_wine_type_id'].unique()
# Out:
# array([ 2,  1,  4,  3, 24,  7, 25], dtype=int64)

# %%
df[df['vintage_wine_type_id']== 25] # drop 예정
# Out:
#       vintage_id                    vintage_name vintage_year  vintage_price  \
# 1448     1595873  Gran Duque d'Alba Gran Reserva         N.V.          60377
#
#       vintage_ratings_average  vintage_ratings_count  vintage_wine_id  \
# 1448                      4.1                    163          1157631
#
#                         vintage_wine_name vintage_winery vintage_country  ...  \
# 1448  Gran Duque d'Alba Gran Reserva N.V.            NaN           Spain  ...
#
#      acidity  fizziness  intensity  sweetness  tannin       flavor  \
# 1448     NaN        NaN        NaN        NaN     NaN  dried_fruit
#
#       varietal_name body_description acidity_description foods
# 1448  Saint-Estèphe      Full-bodied                High    []
#
# [1 rows x 22 columns]

# %%
vintage_wine_type_id_dic = {
    1 : 'Red',
    2 : 'White',
    3 : 'Sparkling',
    4 : 'Rose',
    7 : 'Dessert',
    24 : 'Fortified',
    25 : 'Unknown'
}

# %%
df['vintage_wine_type_id'] = df['vintage_wine_type_id'].apply(lambda x: vintage_wine_type_id_dic[x])

# %%
df = df.rename(columns={'vintage_wine_type_id': 'vintage_wine_type'})

# %%
df['vintage_wine_type']
# Out:
# 0           White
# 1             Red
# 2             Red
# 3            Rose
# 4       Sparkling
#           ...
# 2020          Red
# 2021        White
# 2022    Sparkling
# 2023        White
# 2024    Sparkling
# Name: vintage_wine_type, Length: 2024, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2024 entries, 0 to 2024
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vintage_id               2024 non-null   int64
#  1   vintage_name             2024 non-null   object
#  2   vintage_year             2024 non-null   object
#  3   vintage_price            2024 non-null   int64
#  4   vintage_ratings_average  2024 non-null   float64
#  5   vintage_ratings_count    2024 non-null   int64
#  6   vintage_wine_id          2024 non-null   int64
#  7   vintage_wine_name        2024 non-null   object
#  8   vintage_winery           2023 non-null   object
#  9   vintage_country          2024 non-null   object
#  10  vintage_region           2024 non-null   object
#  11  vintage_wine_type        2024 non-null   object
#  12  acidity                  1970 non-null   float64
#  13  fizziness                111 non-null    float64
#  14  intensity                1970 non-null   float64
#  15  sweetness                1859 non-null   float64
#  16  tannin                   1409 non-null   float64
#  17  flavor                   2021 non-null   object
#  18  varietal_name            2024 non-null   object
#  19  body_description         2024 non-null   object
#  20  acidity_description      2024 non-null   object
#  21  foods                    2024 non-null   object
# dtypes: float64(6), int64(4), object(12)
# memory usage: 363.7+ KB

# %% [markdown]
# ## "foods" 컬럼 값 문자열의 나열로 변환

# %%
type(df['foods'][0])
# Out:
# str

# %%
# literal_eval: 문자열을 파이썬 코드로 파싱 처리
from ast import literal_eval

# str -> lst(dict) 변환
df['foods'] = df['foods'].apply(literal_eval)

# %%
type(df['foods'][0])
# Out:
# list

# %%
df['foods'] = df['foods'].apply(lambda food: ', '.join(food) if isinstance(food, list) else food)

# %%
type(df['foods'][0])
# Out:
# str

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2024 entries, 0 to 2024
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   vintage_id               2024 non-null   int64
#  1   vintage_name             2024 non-null   object
#  2   vintage_year             2024 non-null   object
#  3   vintage_price            2024 non-null   int64
#  4   vintage_ratings_average  2024 non-null   float64
#  5   vintage_ratings_count    2024 non-null   int64
#  6   vintage_wine_id          2024 non-null   int64
#  7   vintage_wine_name        2024 non-null   object
#  8   vintage_winery           2023 non-null   object
#  9   vintage_country          2024 non-null   object
#  10  vintage_region           2024 non-null   object
#  11  vintage_wine_type        2024 non-null   object
#  12  acidity                  1970 non-null   float64
#  13  fizziness                111 non-null    float64
#  14  intensity                1970 non-null   float64
#  15  sweetness                1859 non-null   float64
#  16  tannin                   1409 non-null   float64
#  17  flavor                   2021 non-null   object
#  18  varietal_name            2024 non-null   object
#  19  body_description         2024 non-null   object
#  20  acidity_description      2024 non-null   object
#  21  foods                    2024 non-null   object
# dtypes: float64(6), int64(4), object(12)
# memory usage: 428.2+ KB

# %%
# DataFrame을 CSV 파일로 저장
df.to_csv('data_cleansed.csv', index=False, encoding='utf-8-sig')
print("DataFrame이 data_cleansed.csv로 저장되었습니다.")
# Out:
# DataFrame이 data_cleansed.csv로 저장되었습니다.

# %% [markdown]
# ## EDA

# %%
corr_matrix = df.corr(numeric_only=True)
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
sns.set(style="whitegrid")
    
sns.scatterplot(data=df, x='body_description', y='acidity_description', hue='vintage_wine_type', style='foods', legend=False)
# Out:
# <Axes: xlabel='body_description', ylabel='acidity_description'>

# %%
sns.set(style="whitegrid")

sns.scatterplot(data=df, x='acidity', y='intensity', hue='foods', style='vintage_wine_type', legend=False)
# Out:
# <Axes: xlabel='acidity', ylabel='intensity'>

# %% [markdown]
# # 유사한 음식과 페어링 되는 와인 추천

# %%
df[df['varietal_name'] == 'Riesling']['foods'].unique()
# Out:
# array(['Pork, Shellfish, Spicy food, Poultry, Cured Meat',
#        'Pork, Rich fish (salmon, tuna etc), Spicy food, Vegetarian, Cured Meat',
#        ''], dtype=object)

# %% [markdown]
# ### 벡터 변환

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer = CountVectorizer(ngram_range=(1,2))
foods_vec = count_vectorizer.fit_transform(df['foods'])
foods_vec.shape
# Out:
# (2024, 158)

# %%
foods_vec_vocab = count_vectorizer.vocabulary_
foods_vec_vocab
# Out:
# {'pork': 95,
#  'shellfish': 115,
#  'spicy': 132,
#  'food': 51,
#  'poultry': 103,
#  'cured': 27,
#  'meat': 77,
#  'pork shellfish': 100,
#  'shellfish spicy': 122,
#  'spicy food': 133,
#  'food poultry': 54,
#  'poultry cured': 106,
#  'cured meat': 28,
#  'beef': 10,
#  'lamb': 67,
#  'game': 59,
#  'deer': 29,
#  'venison': 150,
#  'beef lamb': 12,
#  'lamb game': 68,
#  'game deer': 60,
#  'deer venison': 30,
#  'venison poultry': 155,
#  'vegetarian': 143,
#  'shellfish vegetarian': 123,
#  'vegetarian poultry': 149,
#  'rich': 111,
#  'fish': 44,
#  'salmon': 113,
#  'tuna': 136,
#  'etc': 39,
#  'mild': 78,
#  'and': 0,
#  'soft': 130,
#  'cheese': 18,
#  'pork rich': 99,
#  'rich fish': 112,
#  'fish salmon': 50,
#  'salmon tuna': 114,
#  'tuna etc': 137,
#  'etc shellfish': 41,
#  'shellfish mild': 120,
#  'mild and': 79,
#  'and soft': 3,
#  'soft cheese': 131,
#  'sweet': 134,
#  'desserts': 31,
#  'mature': 75,
#  'hard': 63,
#  'blue': 16,
#  'sweet desserts': 135,
#  'desserts mature': 35,
#  'mature and': 76,
#  'and hard': 1,
#  'hard cheese': 64,
#  'cheese blue': 20,
#  'blue cheese': 17,
#  'fruity': 57,
#  'fruity desserts': 58,
#  'desserts blue': 34,
#  'lamb pork': 69,
#  'pork poultry': 98,
#  'veal': 138,
#  'lamb veal': 71,
#  'veal poultry': 142,
#  'pasta': 88,
#  'beef pasta': 13,
#  'pasta veal': 93,
#  'beef veal': 14,
#  'veal game': 140,
#  'pasta lamb': 89,
#  'appetizers': 8,
#  'snacks': 124,
#  'lean': 73,
#  'shellfish appetizers': 117,
#  'appetizers and': 9,
#  'and snacks': 2,
#  'snacks lean': 128,
#  'lean fish': 74,
#  'fish cured': 46,
#  'venison mature': 153,
#  'cheese poultry': 25,
#  'pasta rich': 91,
#  'cheese cured': 21,
#  'goat': 61,
#  'milk': 80,
#  'lamb vegetarian': 72,
#  'poultry goat': 107,
#  'goat milk': 62,
#  'milk cheese': 81,
#  'any': 4,
#  'junk': 65,
#  'will': 156,
#  'do': 37,
#  'aperitif': 6,
#  'shellfish any': 116,
#  'any junk': 5,
#  'junk food': 66,
#  'food will': 56,
#  'will do': 157,
#  'do appetizers': 38,
#  'fish aperitif': 45,
#  'pork vegetarian': 102,
#  'poultry appetizers': 104,
#  'venison blue': 151,
#  'etc mature': 40,
#  'lamb poultry': 70,
#  'mushrooms': 82,
#  'veal pork': 141,
#  'poultry mushrooms': 110,
#  'aperitif cured': 7,
#  'cheese aperitif': 19,
#  'pork game': 96,
#  'etc spicy': 42,
#  'food vegetarian': 55,
#  'vegetarian cured': 145,
#  'pasta vegetarian': 94,
#  'vegetarian appetizers': 144,
#  'fish mild': 48,
#  'etc vegetarian': 43,
#  'venison cured': 152,
#  'venison mushrooms': 154,
#  'cheese fruity': 22,
#  'pork spicy': 101,
#  'food mushrooms': 53,
#  'mushrooms cured': 85,
#  'pasta shellfish': 92,
#  'shellfish mature': 119,
#  'cheese lean': 24,
#  'veal cured': 139,
#  'vegetarian goat': 146,
#  'beef game': 11,
#  'mushrooms blue': 84,
#  'poultry mild': 109,
#  'pork mature': 97,
#  'poultry blue': 105,
#  'mushrooms mild': 87,
#  'vegetarian mushrooms': 148,
#  'mushrooms aperitif': 83,
#  'desserts aperitif': 32,
#  'vegetarian lean': 147,
#  'cheese goat': 23,
#  'pasta pork': 90,
#  'shellfish poultry': 121,
#  'poultry lean': 108,
#  'fish goat': 47,
#  'snacks mild': 129,
#  'desserts appetizers': 33,
#  'snacks fruity': 126,
#  'cheese vegetarian': 26,
#  'food appetizers': 52,
#  'snacks aperitif': 125,
#  'snacks goat': 127,
#  'desserts mild': 36,
#  'beef vegetarian': 15,
#  'shellfish lean': 118,
#  'fish mushrooms': 49,
#  'mushrooms goat': 86}

# %%
foods_vec_feature_names = pd.DataFrame(count_vectorizer.get_feature_names_out())
foods_vec_feature_names
# Out:
#                      0
# 0                  and
# 1             and hard
# 2           and snacks
# 3             and soft
# 4                  any
# ..                 ...
# 153     venison mature
# 154  venison mushrooms
# 155    venison poultry
# 156               will
# 157            will do
#
# [158 rows x 1 columns]

# %% [markdown]
# ### 코사인 유사도 측정

# %%
from sklearn.metrics.pairwise import cosine_similarity

foods_sim = cosine_similarity(foods_vec, foods_vec)
print(foods_sim[:5])
# Out:
# [[1.         0.0836242  0.0836242  ... 0.         0.         0.        ]
#  [0.0836242  1.         1.         ... 0.         0.         0.        ]
#  [0.0836242  1.         1.         ... 0.         0.         0.        ]
#  [0.41931393 0.11396058 0.11396058 ... 0.         0.         0.        ]
#  [0.12104551 0.         0.         ... 0.08247861 0.         0.08247861]]

# %%
# 각 영화별 장르 유사도 높은 영화 추출
wine_idx_by_foods_sim = foods_sim.argsort(axis=1)[:, ::-1]
print(wine_idx_by_foods_sim[:5])
# Out:
# [[   0 1267 1370 ...  513 1275 2023]
#  [ 604  235 1098 ... 1245 1237 2023]
#  [ 604  235 1098 ... 1245 1237 2023]
#  [1826    3 1011 ...  946  945 2023]
#  [ 523 1254  393 ... 1784 1042  799]]

# %%
# 0번 와인 1896 Riesling 2023 와 장르 유사도 높은 와인
wine_idx = 0
df.iloc[wine_idx_by_foods_sim[wine_idx, :10]]
# Out:
#       vintage_id                                       vintage_name  \
# 0      177404982                     Carl Loewen 1896 Riesling 2023
# 1267    15852718  Fritz Haag Riesling Trocken Brauneberger Juffe...
# 1370   171254236            Amisfield Lowburn Terrace Riesling 2022
# 1431   143110020  Von Winning Ruppertsberger Reiterpfad Riesling...
# 1481   168894912            Pegasus Bay Bel Canto Dry Riesling 2020
# 1488   156292767               Prinz Salm Two Princes Riesling 2017
# 1521        7058                    Argyle Minus Five Riesling 2007
# 1537   177404970       Carl Loewen Alte Reben Riesling Trocken 2023
# 1595   143139629                  Deinhard Piesporter Riesling 2016
# 1619     7851738  Schloss Johannisberg Gelblack Riesling Trocken...
#
#      vintage_year  vintage_price  vintage_ratings_average  \
# 0            2023          82045                      5.0
# 1267         2007         107815                      4.1
# 1370         2022          32885                      4.1
# 1431         2015          68959                      4.1
# 1481         2020          32885                      4.1
# 1488         2017          55201                      4.1
# 1521         2007          62533                      4.1
# 1537         2023          20138                      4.1
# 1595         2016          25876                      4.1
# 1619         2006          46576                      4.0
#
#       vintage_ratings_count  vintage_wine_id  \
# 0                       115          1945087
# 1267                   2501          2242419
# 1370                    352            86254
# 1431                    194          1577058
# 1481                    109          1261670
# 1488                    102          2705003
# 1521                     65             6417
# 1537                     52          1175944
# 1595                     29          1155969
# 1619                  13406          2130558
#
#                                       vintage_wine_name        vintage_winery  \
# 0                                    1896 Riesling 2023           Carl Loewen
# 1267  Riesling Trocken Brauneberger Juffer Sonnenuhr...            Fritz Haag
# 1370                      Lowburn Terrace Riesling 2022             Amisfield
# 1431            Ruppertsberger Reiterpfad Riesling 2015           Von Winning
# 1481                        Bel Canto Dry Riesling 2020           Pegasus Bay
# 1488                          Two Princes Riesling 2017            Prinz Salm
# 1521                           Minus Five Riesling 2007                Argyle
# 1537                   Alte Reben Riesling Trocken 2023           Carl Loewen
# 1595                           Piesporter Riesling 2016              Deinhard
# 1619                     Gelblack Riesling Trocken 2006  Schloss Johannisberg
#
#      vintage_country  ... acidity fizziness  intensity  sweetness  tannin  \
# 0            Germany  ...    4.61       NaN       3.32       2.05     NaN
# 1267         Germany  ...    4.41       NaN       3.16       1.91     NaN
# 1370     New Zealand  ...    4.38       NaN       2.53       2.48     NaN
# 1431         Germany  ...    4.48       NaN       3.23       1.75     NaN
# 1481     New Zealand  ...    4.35       NaN       2.87       1.85     NaN
# 1488         Germany  ...    4.52       NaN       2.83       2.45     NaN
# 1521   United States  ...    3.99       NaN       2.50       2.41     NaN
# 1537         Germany  ...    4.40       NaN       3.03       2.00     NaN
# 1595         Germany  ...    4.76       NaN       2.87       2.34     NaN
# 1619         Germany  ...    4.63       NaN       2.97       1.66     NaN
#
#           flavor  varietal_name body_description acidity_description  \
# 0     tree_fruit       Riesling     Light-bodied                High
# 1267       earth       Riesling     Light-bodied                High
# 1370  tree_fruit       Riesling     Light-bodied                High
# 1431       earth       Riesling     Light-bodied                High
# 1481       earth       Riesling     Light-bodied                High
# 1488  tree_fruit       Riesling     Light-bodied                High
# 1521  tree_fruit       Riesling    Medium-bodied                High
# 1537  tree_fruit       Riesling     Light-bodied                High
# 1595  tree_fruit       Riesling     Light-bodied                High
# 1619  tree_fruit       Riesling     Light-bodied                High
#
#                                                  foods
# 0     Pork, Shellfish, Spicy food, Poultry, Cured Meat
# 1267  Pork, Shellfish, Spicy food, Poultry, Cured Meat
# 1370  Pork, Shellfish, Spicy food, Poultry, Cured Meat
# 1431  Pork, Shellfish, Spicy food, Poultry, Cured Meat
# 1481  Pork, Shellfish, Spicy food, Poultry, Cured Meat
# 1488  Pork, Shellfish, Spicy food, Poultry, Cured Meat
# 1521  Pork, Shellfish, Spicy food, Poultry, Cured Meat
# 1537  Pork, Shellfish, Spicy food, Poultry, Cured Meat
# 1595  Pork, Shellfish, Spicy food, Poultry, Cured Meat
# 1619  Pork, Shellfish, Spicy food, Poultry, Cured Meat
#
# [10 rows x 22 columns]

# %% [markdown]
# ## 새로운 데이터 입력 및 유사도 분석

# %%
df_new_row = pd.DataFrame({
    'vintage_id': [None],
    'vintage_name': [None],
    'vintage_year': [None],
    'vintage_price': [None],
    'vintage_ratings_average': [None],
    'vintage_ratings_count': [None],
    'vintage_wine_id': [None],
    'vintage_wine_name': [None],
    'vintage_winery': [None],
    'vintage_country': [None],
    'vintage_region': [None],
    'vintage_wine_type': [None],
    'acidity': [None],
    'fizziness': [None],
    'intensity': [None],
    'sweetness': [None],
    'tannin': [None],
    'flavor': [None],
    'varietal_name': [None],
    'body_description': [None],
    'acidity_description': [None],
    'foods': [['raw fish, lemon, pasta']] 
})

# %%
# literal_eval: 문자열을 파이썬 코드로 파싱 처리
# from ast import literal_eval
# 
# # str -> lst(dict) 변환
# df_new_row['foods'] = df_new_row['foods'].apply(literal_eval)

df_new_row['foods'] = df_new_row['foods'].apply(lambda food: ', '.join(food) if isinstance(food, list) else food)

# %%
df = pd.concat([df, df_new_row], ignore_index=True)
# Out:
# C:\Users\playdata2\AppData\Local\Temp\ipykernel_3752\1354684799.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, df_new_row], ignore_index=True)

# %%
df.tail()
# Out:
#      vintage_id                                       vintage_name  \
# 2020  164818931  Château Olivier Pessac-Léognan Blanc (Grand Cr...
# 2021   23213221                      Costaripa Mattia Vezzola Brut
# 2022  169670734              Pegasus Bay Sauvignon - Sémillon 2021
# 2023    4046901              Abbazia di S. Gaudenzio Moscato Dolce
# 2024       None                                               None
#
#      vintage_year vintage_price  vintage_ratings_average  \
# 2020         1964        316991                      3.9
# 2021         N.V.         37964                      3.9
# 2022         2021         23017                      3.9
# 2023         N.V.         25876                      3.9
# 2024         None          None                      NaN
#
#      vintage_ratings_count vintage_wine_id  \
# 2020                  2033           87425
# 2021                  2006         3429423
# 2022                  1905           16114
# 2023                  1822         2115561
# 2024                  None            None
#
#                                       vintage_wine_name  \
# 2020  Pessac-Léognan Blanc (Grand Cru Classé de Grav...
# 2021                           Mattia Vezzola Brut N.V.
# 2022                          Sauvignon - Sémillon 2021
# 2023                                 Moscato Dolce N.V.
# 2024                                               None
#
#                vintage_winery vintage_country  ... acidity fizziness  \
# 2020          Château Olivier          France  ...    3.17       NaN
# 2021                Costaripa           Italy  ...    3.29      3.82
# 2022              Pegasus Bay     New Zealand  ...     NaN       NaN
# 2023  Abbazia di S. Gaudenzio           Italy  ...    3.01      3.94
# 2024                     None            None  ...     NaN       NaN
#
#       intensity  sweetness  tannin        flavor  varietal_name  \
# 2020       3.80       1.96     NaN  citrus_fruit          White
# 2021       2.89        NaN     NaN    tree_fruit      Sparkling
# 2022        NaN        NaN     NaN  citrus_fruit      Sparkling
# 2023       3.02        NaN     NaN    tree_fruit      Sparkling
# 2024        NaN        NaN     NaN          None           None
#
#      body_description acidity_description  \
# 2020    Medium-bodied                High
# 2021    Medium-bodied              Medium
# 2022    Medium-bodied              Medium
# 2023    Medium-bodied              Medium
# 2024             None                None
#
#                                                   foods
# 2020  Pork, Vegetarian, Poultry, Appetizers and snac...
# 2021                    Appetizers and snacks, Aperitif
# 2022
# 2023                    Appetizers and snacks, Aperitif
# 2024                             raw fish, lemon, pasta
#
# [5 rows x 22 columns]

# %% [markdown]
# ### 벡터 변환

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer = CountVectorizer(ngram_range=(1,3))
foods_vec = count_vectorizer.fit_transform(df['foods'])
foods_vec.shape
# Out:
# (2025, 342)

# %%
foods_vec_vocab = count_vectorizer.vocabulary_
foods_vec_vocab
# Out:
# {'pork': 203,
#  'shellfish': 248,
#  'spicy': 285,
#  'food': 107,
#  'poultry': 223,
#  'cured': 57,
#  'meat': 167,
#  'pork shellfish': 213,
#  'shellfish spicy': 261,
#  'spicy food': 286,
#  'food poultry': 112,
#  'poultry cured': 228,
#  'cured meat': 58,
#  'pork shellfish spicy': 216,
#  'shellfish spicy food': 262,
#  'spicy food poultry': 289,
#  'food poultry cured': 113,
#  'poultry cured meat': 229,
#  'beef': 20,
#  'lamb': 141,
#  'game': 125,
#  'deer': 59,
#  'venison': 329,
#  'beef lamb': 23,
#  'lamb game': 142,
#  'game deer': 126,
#  'deer venison': 60,
#  'venison poultry': 337,
#  'beef lamb game': 24,
#  'lamb game deer': 143,
#  'game deer venison': 127,
#  'deer venison poultry': 65,
#  'vegetarian': 313,
#  'shellfish vegetarian': 263,
#  'vegetarian poultry': 324,
#  'pork shellfish vegetarian': 217,
#  'shellfish vegetarian poultry': 267,
#  'rich': 242,
#  'fish': 92,
#  'salmon': 245,
#  'tuna': 297,
#  'etc': 80,
#  'mild': 168,
#  'and': 0,
#  'soft': 279,
#  'cheese': 39,
#  'pork rich': 211,
#  'rich fish': 243,
#  'fish salmon': 105,
#  'salmon tuna': 246,
#  'tuna etc': 298,
#  'etc shellfish': 83,
#  'shellfish mild': 257,
#  'mild and': 169,
#  'and soft': 9,
#  'soft cheese': 280,
#  'pork rich fish': 212,
#  'rich fish salmon': 244,
#  'fish salmon tuna': 106,
#  'salmon tuna etc': 247,
#  'tuna etc shellfish': 300,
#  'etc shellfish mild': 86,
#  'shellfish mild and': 258,
#  'mild and soft': 170,
#  'and soft cheese': 10,
#  'sweet': 291,
#  'desserts': 66,
#  'mature': 164,
#  'hard': 131,
#  'blue': 36,
#  'sweet desserts': 292,
#  'desserts mature': 73,
#  'mature and': 165,
#  'and hard': 1,
#  'hard cheese': 132,
#  'cheese blue': 41,
#  'blue cheese': 37,
#  'sweet desserts mature': 295,
#  'desserts mature and': 74,
#  'mature and hard': 166,
#  'and hard cheese': 2,
#  'hard cheese blue': 133,
#  'cheese blue cheese': 42,
#  'fruity': 121,
#  'fruity desserts': 122,
#  'desserts blue': 71,
#  'fruity desserts blue': 124,
#  'desserts blue cheese': 72,
#  'lamb pork': 144,
#  'pork poultry': 208,
#  'lamb pork poultry': 147,
#  'veal': 303,
#  'lamb veal': 150,
#  'veal poultry': 311,
#  'beef lamb veal': 27,
#  'lamb veal poultry': 152,
#  'veal poultry cured': 312,
#  'pasta': 184,
#  'beef pasta': 28,
#  'pasta veal': 195,
#  'beef pasta veal': 30,
#  'pasta veal poultry': 198,
#  'beef veal': 31,
#  'veal game': 306,
#  'beef veal game': 32,
#  'veal game deer': 307,
#  'pasta lamb': 185,
#  'beef pasta lamb': 29,
#  'pasta lamb veal': 188,
#  'lamb veal game': 151,
#  'appetizers': 17,
#  'snacks': 268,
#  'lean': 155,
#  'shellfish appetizers': 251,
#  'appetizers and': 18,
#  'and snacks': 3,
#  'snacks lean': 275,
#  'lean fish': 156,
#  'fish cured': 95,
#  'shellfish appetizers and': 252,
#  'appetizers and snacks': 19,
#  'and snacks lean': 7,
#  'snacks lean fish': 276,
#  'lean fish cured': 158,
#  'fish cured meat': 96,
#  'venison mature': 334,
#  'cheese poultry': 51,
#  'deer venison mature': 63,
#  'venison mature and': 335,
#  'hard cheese poultry': 136,
#  'pasta rich': 191,
#  'cheese cured': 43,
#  'pasta rich fish': 192,
#  'soft cheese cured': 282,
#  'cheese cured meat': 44,
#  'sweet desserts blue': 294,
#  'goat': 128,
#  'milk': 171,
#  'lamb vegetarian': 153,
#  'poultry goat': 230,
#  'goat milk': 129,
#  'milk cheese': 172,
#  'lamb vegetarian poultry': 154,
#  'vegetarian poultry goat': 326,
#  'poultry goat milk': 231,
#  'goat milk cheese': 130,
#  'any': 11,
#  'junk': 138,
#  'will': 339,
#  'do': 77,
#  'aperitif': 14,
#  'shellfish any': 249,
#  'any junk': 12,
#  'junk food': 139,
#  'food will': 119,
#  'will do': 340,
#  'do appetizers': 78,
#  'fish aperitif': 93,
#  'shellfish any junk': 250,
#  'any junk food': 13,
#  'junk food will': 140,
#  'food will do': 120,
#  'will do appetizers': 341,
#  'do appetizers and': 79,
#  'lean fish aperitif': 157,
#  'pork vegetarian': 220,
#  'poultry appetizers': 224,
#  'pork vegetarian poultry': 222,
#  'vegetarian poultry appetizers': 325,
#  'poultry appetizers and': 225,
#  'venison blue': 330,
#  'deer venison blue': 61,
#  'venison blue cheese': 331,
#  'etc mature': 81,
#  'tuna etc mature': 299,
#  'etc mature and': 82,
#  'cheese poultry cured': 53,
#  'beef lamb pork': 25,
#  'lamb poultry': 148,
#  'pasta lamb poultry': 187,
#  'pasta lamb game': 186,
#  'mushrooms': 174,
#  'veal pork': 308,
#  'poultry mushrooms': 236,
#  'veal pork poultry': 310,
#  'pork poultry mushrooms': 210,
#  'aperitif cured': 15,
#  'fish aperitif cured': 94,
#  'aperitif cured meat': 16,
#  'cheese aperitif': 40,
#  'blue cheese aperitif': 38,
#  'pork game': 204,
#  'pasta veal pork': 197,
#  'veal pork game': 309,
#  'pork game deer': 205,
#  'etc spicy': 88,
#  'food vegetarian': 116,
#  'vegetarian cured': 316,
#  'tuna etc spicy': 301,
#  'etc spicy food': 89,
#  'spicy food vegetarian': 290,
#  'food vegetarian cured': 117,
#  'vegetarian cured meat': 317,
#  'pasta vegetarian': 199,
#  'vegetarian appetizers': 314,
#  'pasta vegetarian appetizers': 200,
#  'vegetarian appetizers and': 315,
#  'fish mild': 101,
#  'lean fish mild': 160,
#  'fish mild and': 102,
#  'soft cheese aperitif': 281,
#  'etc vegetarian': 90,
#  'tuna etc vegetarian': 302,
#  'etc vegetarian poultry': 91,
#  'venison cured': 332,
#  'deer venison cured': 62,
#  'venison cured meat': 333,
#  'venison mushrooms': 336,
#  'deer venison mushrooms': 64,
#  'cheese fruity': 45,
#  'hard cheese fruity': 134,
#  'cheese fruity desserts': 46,
#  'pork spicy': 218,
#  'food mushrooms': 110,
#  'mushrooms cured': 178,
#  'pork spicy food': 219,
#  'spicy food mushrooms': 288,
#  'food mushrooms cured': 111,
#  'mushrooms cured meat': 179,
#  'pasta shellfish': 193,
#  'shellfish mature': 255,
#  'cheese lean': 49,
#  'pasta shellfish mature': 194,
#  'shellfish mature and': 256,
#  'hard cheese lean': 135,
#  'cheese lean fish': 50,
#  'veal cured': 304,
#  'pasta veal cured': 196,
#  'veal cured meat': 305,
#  'beef lamb poultry': 26,
#  'vegetarian goat': 318,
#  'shellfish vegetarian goat': 265,
#  'vegetarian goat milk': 319,
#  'beef game': 21,
#  'beef game deer': 22,
#  'mushrooms blue': 176,
#  'poultry mushrooms blue': 237,
#  'mushrooms blue cheese': 177,
#  'poultry mild': 234,
#  'food poultry mild': 115,
#  'poultry mild and': 235,
#  'pork mature': 206,
#  'poultry blue': 226,
#  'lamb pork mature': 146,
#  'pork mature and': 207,
#  'cheese poultry blue': 52,
#  'poultry blue cheese': 227,
#  'mushrooms mild': 182,
#  'cheese poultry mushrooms': 54,
#  'poultry mushrooms mild': 238,
#  'mushrooms mild and': 183,
#  'vegetarian mushrooms': 322,
#  'mushrooms aperitif': 175,
#  'shellfish vegetarian mushrooms': 266,
#  'vegetarian mushrooms aperitif': 323,
#  'shellfish vegetarian appetizers': 264,
#  'desserts aperitif': 67,
#  'fruity desserts aperitif': 123,
#  'vegetarian lean': 320,
#  'cheese goat': 47,
#  'pork vegetarian lean': 221,
#  'vegetarian lean fish': 321,
#  'soft cheese goat': 284,
#  'cheese goat milk': 48,
#  'pasta pork': 189,
#  'shellfish poultry': 259,
#  'pasta pork shellfish': 190,
#  'pork shellfish poultry': 215,
#  'poultry lean': 232,
#  'pasta vegetarian poultry': 202,
#  'vegetarian poultry lean': 327,
#  'poultry lean fish': 233,
#  'food vegetarian goat': 118,
#  'lamb pork game': 145,
#  'etc shellfish vegetarian': 87,
#  'fish goat': 97,
#  'food poultry lean': 114,
#  'lean fish goat': 159,
#  'fish goat milk': 98,
#  'milk cheese cured': 173,
#  'lamb poultry blue': 149,
#  'pasta vegetarian cured': 201,
#  'snacks mild': 277,
#  'and snacks mild': 8,
#  'snacks mild and': 278,
#  'vegetarian poultry mild': 328,
#  'desserts appetizers': 69,
#  'sweet desserts appetizers': 293,
#  'desserts appetizers and': 70,
#  'snacks fruity': 271,
#  'and snacks fruity': 5,
#  'snacks fruity desserts': 272,
#  'desserts aperitif cured': 68,
#  'cheese vegetarian': 55,
#  'pork shellfish mature': 214,
#  'hard cheese vegetarian': 137,
#  'cheese vegetarian lean': 56,
#  'food appetizers': 108,
#  'spicy food appetizers': 287,
#  'food appetizers and': 109,
#  'pork poultry cured': 209,
#  'shellfish poultry appetizers': 260,
#  'snacks aperitif': 269,
#  'and snacks aperitif': 4,
#  'snacks aperitif cured': 270,
#  'snacks goat': 273,
#  'etc shellfish appetizers': 84,
#  'and snacks goat': 6,
#  'snacks goat milk': 274,
#  'desserts mild': 75,
#  'sweet desserts mild': 296,
#  'desserts mild and': 76,
#  'soft cheese fruity': 283,
#  'beef vegetarian': 34,
#  'beef vegetarian poultry': 35,
#  'venison poultry mild': 338,
#  'shellfish lean': 253,
#  'fish mushrooms': 103,
#  'mushrooms goat': 180,
#  'etc shellfish lean': 85,
#  'shellfish lean fish': 254,
#  'lean fish mushrooms': 161,
#  'fish mushrooms goat': 104,
#  'mushrooms goat milk': 181,
#  'beef veal poultry': 33,
#  'raw': 239,
#  'lemon': 162,
#  'raw fish': 240,
#  'fish lemon': 99,
#  'lemon pasta': 163,
#  'raw fish lemon': 241,
#  'fish lemon pasta': 100}

# %%
foods_vec_feature_names = pd.DataFrame(count_vectorizer.get_feature_names_out())
foods_vec_feature_names
# Out:
#                         0
# 0                     and
# 1                and hard
# 2         and hard cheese
# 3              and snacks
# 4     and snacks aperitif
# ..                    ...
# 337       venison poultry
# 338  venison poultry mild
# 339                  will
# 340               will do
# 341    will do appetizers
#
# [342 rows x 1 columns]

# %% [markdown]
# ### 코사인 유사도 측정

# %%
foods_sim = cosine_similarity(foods_vec, foods_vec)
# foods_sim[:10]

# %%
wine_idx_by_foods_sim = foods_sim.argsort(axis=1)[:, ::-1]
print(wine_idx_by_foods_sim[:5])
# Out:
# [[   0  796 1881 ...  877  876 2024]
#  [ 775 1532  301 ...  948  938 1012]
#  [ 775 1532  301 ...  948  938 1012]
#  [1826    3 1011 ...  420 1088 2024]
#  [ 657  411  222 ... 1004 1005  765]]

# %%
#  추가된 와인 과 푸드 유사도 높은 와인
wine_idx = len(df) -1
df_recommended = df.iloc[wine_idx_by_foods_sim[wine_idx, :]]
df_recommended
# Out:
#      vintage_id                                       vintage_name  \
# 2024       None                                               None
# 1016  152659861              Domaine Les Aurelles Aurel Blanc 2017
# 1852  174954957                 Domaine Lafage Miraflors Rosé 2023
# 176    29884594  La Grange des Pères Vin de Pays de l'Hérault 2015
# 1589  161643186                           Sartarelli Balciana 2019
# ...         ...                                                ...
# 1201  159509471                     Trinity Hill Homage Syrah 2019
# 1202  159789928                      Mills Reef Elspeth Syrah 2018
# 1207    2230598            Château Phélan Ségur Saint-Estèphe 1973
# 1208   15780559  Château Branaire-Ducru Saint-Julien (Grand Cru...
# 0     177404982                     Carl Loewen 1896 Riesling 2023
#
#      vintage_year vintage_price  vintage_ratings_average  \
# 2024         None          None                      NaN
# 1016         2017        192686                      4.2
# 1852         2023         16334                      4.0
# 176          2015        447517                      4.5
# 1589         2019         62712                      4.1
# ...           ...           ...                      ...
# 1201         2019        131564                      4.2
# 1202         2018         41108                      4.2
# 1207         1973        246134                      4.1
# 1208         1959        615335                      4.1
# 0            2023         82045                      5.0
#
#      vintage_ratings_count vintage_wine_id  \
# 2024                  None            None
# 1016                   213         2424533
# 1852                   101         1614560
# 176                    772          779852
# 1589                    32           85568
# ...                    ...             ...
# 1201                    25           17607
# 1202                    25         1257519
# 1207                 29845           98166
# 1208                 26256         1172272
# 0                      115         1945087
#
#                          vintage_wine_name          vintage_winery  \
# 2024                                  None                    None
# 1016                      Aurel Blanc 2017    Domaine Les Aurelles
# 1852                   Miraflors Rosé 2023          Domaine Lafage
# 176          Vin de Pays de l'Hérault 2015     La Grange des Pères
# 1589                         Balciana 2019              Sartarelli
# ...                                    ...                     ...
# 1201                     Homage Syrah 2019            Trinity Hill
# 1202                    Elspeth Syrah 2018              Mills Reef
# 1207                    Saint-Estèphe 1973    Château Phélan Ségur
# 1208  Saint-Julien (Grand Cru Classé) 1959  Château Branaire-Ducru
# 0                       1896 Riesling 2023             Carl Loewen
#
#      vintage_country  ... fizziness intensity  sweetness  tannin       flavor  \
# 2024            None  ...       NaN       NaN        NaN     NaN         None
# 1016          France  ...       NaN      3.91       2.07     NaN        earth
# 1852          France  ...       NaN      2.86       1.30     NaN    red_fruit
# 176           France  ...       NaN      3.88       1.81    3.47        earth
# 1589           Italy  ...       NaN      3.61       2.42     NaN        earth
# ...              ...  ...       ...       ...        ...     ...          ...
# 1201     New Zealand  ...       NaN      3.82       1.61    3.64  black_fruit
# 1202     New Zealand  ...       NaN      3.84       1.77    3.42  black_fruit
# 1207          France  ...       NaN      4.22       1.62    4.27          oak
# 1208          France  ...       NaN      3.79       1.61    3.91          oak
# 0            Germany  ...       NaN      3.32       2.05     NaN   tree_fruit
#
#       varietal_name  body_description acidity_description  \
# 2024           None              None                None
# 1016          White       Full-bodied                High
# 1852           Rosé       Full-bodied                High
# 176             Red       Full-bodied                High
# 1589          White     Medium-bodied                High
# ...             ...               ...                 ...
# 1201          Syrah       Full-bodied                High
# 1202          Syrah       Full-bodied                High
# 1207  Saint-Estèphe       Full-bodied                High
# 1208   Saint-Julien       Full-bodied                High
# 0          Riesling      Light-bodied                High
#
#                                                   foods weighted_ratings
# 2024                             raw fish, lemon, pasta              NaN
# 1016    Pasta, Vegetarian, Poultry, Lean fish, Aperitif         4.214912
# 1852  Pasta, Vegetarian, Appetizers and snacks, Lean...          4.16197
# 176                                   Beef, Pasta, Veal         4.433584
# 1589  Pasta, Vegetarian, Appetizers and snacks, Lean...         4.213129
# ...                                                 ...              ...
# 1201          Beef, Lamb, Game (deer, venison), Poultry         4.225144
# 1202          Beef, Lamb, Game (deer, venison), Poultry         4.225144
# 1207          Beef, Lamb, Game (deer, venison), Poultry         4.101056
# 1208          Beef, Lamb, Game (deer, venison), Poultry         4.101199
# 0      Pork, Shellfish, Spicy food, Poultry, Cured Meat         4.471674
#
# [2025 rows x 23 columns]

# %%
# 가중 평점 계산에 필요한 변수
C = df['vintage_ratings_average'].mean() # 전체 영화 평점
m = df['vintage_ratings_count'].quantile(0.5) # 최소 투표 횟수

def weighted_rating():
    v = df['vintage_ratings_count'] # 개별 영화 투표 수
    R = df['vintage_ratings_average'] # 개별 영화 평점
    return (v/(v+m)) * R + (m/(v+m)) * C

df['weighted_ratings'] = weighted_rating(df)
df.sort_values(by='weighted_ratings', ascending=False)
# Out:
#      vintage_id                                       vintage_name  \
# 1       1510217  Château Haut-Brion Pessac-Léognan (Premier Gra...
# 2       2611979  Château Latour Grand Vin Pauillac (Premier Gra...
# 12      2267725                     Château d'Yquem Sauternes 1934
# 13    156103569                           Antinori Tignanello 2018
# 14      3909022  Château Mouton Rothschild Pauillac (Premier Gr...
# ...         ...                                                ...
# 1974  164942655                        Ayala Brut Majeur Champagne
# 1973    5995082  Château de Camensac Haut-Médoc (Grand Cru Clas...
# 1972    2656200                     Decoy California Red Wine 2004
# 1971    4250149        Wente Vineyards Morning Fog Chardonnay 2003
# 2024       None                                               None
#
#      vintage_year vintage_price  vintage_ratings_average  \
# 1            1989       3244496                      4.8
# 2            1982       2759686                      4.8
# 12           1934       2921284                      4.7
# 13           2018        191090                      4.7
# 14           1986       1178461                      4.7
# ...           ...           ...                      ...
# 1974         N.V.         67423                      3.9
# 1973         1937        671275                      3.9
# 1972         2004         72883                      3.9
# 1971         2003         29326                      3.9
# 2024         None          None                      NaN
#
#      vintage_ratings_count vintage_wine_id  \
# 1                     1538         1152755
# 2                     1445         1655970
# 12                   49899         1153863
# 13                    9409            1652
# 14                    2767         1684223
# ...                    ...             ...
# 1974                 14030           12318
# 1973                 18821           63094
# 1972                 21773         1128171
# 1971                 29927            1720
# 2024                  None            None
#
#                                       vintage_wine_name  \
# 1        Pessac-Léognan (Premier Grand Cru Classé) 1989
# 2     Grand Vin Pauillac (Premier Grand Cru Classé) ...
# 12                                       Sauternes 1934
# 13                                      Tignanello 2018
# 14             Pauillac (Premier Grand Cru Classé) 1986
# ...                                                 ...
# 1974                         Brut Majeur Champagne N.V.
# 1973                 Haut-Médoc (Grand Cru Classé) 1937
# 1972                           California Red Wine 2004
# 1971                        Morning Fog Chardonnay 2003
# 2024                                               None
#
#                  vintage_winery vintage_country  ... fizziness intensity  \
# 1            Château Haut-Brion          France  ...       NaN      4.08
# 2                Château Latour          France  ...       NaN      4.12
# 12              Château d'Yquem          France  ...       NaN      4.67
# 13                     Antinori           Italy  ...       NaN      3.43
# 14    Château Mouton Rothschild          France  ...       NaN      4.05
# ...                         ...             ...  ...       ...       ...
# 1974                      Ayala          France  ...      4.26      3.65
# 1973        Château de Camensac          France  ...       NaN      4.16
# 1972                      Decoy   United States  ...       NaN      4.68
# 1971            Wente Vineyards   United States  ...       NaN      4.69
# 2024                       None            None  ...       NaN       NaN
#
#       sweetness  tannin        flavor   varietal_name  body_description  \
# 1          1.67    4.23           oak  Pessac-Léognan       Full-bodied
# 2          1.68    4.13           oak        Pauillac       Full-bodied
# 12         4.87     NaN         earth       Sauternes       Full-bodied
# 13         1.72    2.99           oak             Red     Medium-bodied
# 14         1.72    4.10           oak        Pauillac       Full-bodied
# ...         ...     ...           ...             ...               ...
# 1974        NaN     NaN  citrus_fruit       Champagne     Medium-bodied
# 1973       1.50    4.16           oak      Haut-Médoc       Full-bodied
# 1972       1.69    3.24           oak       Red Blend       Full-bodied
# 1971       2.68     NaN           oak      Chardonnay       Full-bodied
# 2024        NaN     NaN          None            None              None
#
#      acidity_description                                              foods  \
# 1                   High          Beef, Lamb, Game (deer, venison), Poultry
# 2                   High          Beef, Lamb, Game (deer, venison), Poultry
# 12                  High                       Fruity desserts, Blue cheese
# 13                Medium              Beef, Lamb, Veal, Poultry, Cured Meat
# 14                  High          Beef, Lamb, Game (deer, venison), Poultry
# ...                  ...                                                ...
# 1974                High  Pork, Rich fish (salmon, tuna etc), Shellfish,...
# 1973                High                   Beef, Lamb, Game (deer, venison)
# 1972                High                          Beef, Lamb, Veal, Poultry
# 1971              Medium  Pork, Rich fish (salmon, tuna etc), Vegetarian...
# 2024                None                             raw fish, lemon, pasta
#
#      weighted_ratings
# 1            4.720251
# 2            4.715873
# 12           4.697655
# 13           4.687822
# 14           4.661004
# ...               ...
# 1974         3.905714
# 1973         3.904278
# 1972         3.903705
# 1971         3.902704
# 2024              NaN
#
# [2025 rows x 23 columns]

# %%
#  추가된 와인 과 푸드 유사도 높은 와인
wine_idx = len(df) - 1
recommended_idx = wine_idx_by_foods_sim[wine_idx, : 20]
recommended_idx = recommended_idx[recommended_idx != wine_idx]
df_recommended = df.iloc[recommended_idx]

# %%
max_price = 100_000
min_price = 10_000

df_recommended_price_range = df_recommended[(df_recommended['vintage_price'] > min_price) & (df_recommended['vintage_price'] < max_price)]

# %%
df_recommended_ratings = df_recommended_price_range.sort_values(by='weighted_ratings', ascending=False)
# sort_values(by='vintage_price', ascending=True))

# %%
df_recommended_ratings
# Out:
#      vintage_id                                       vintage_name  \
# 1589  161643186                           Sartarelli Balciana 2019
# 1587  150920156                    Domaine Les Aurelles Solen 2016
# 1468  169540536                             La Bollina Narses 2021
# 1460  158762318        Marchese delle Saline Tìade Etna Rosso 2017
# 1442    7514461               Marina Cvetić Riserva Trebbiano 2010
# 1433  161407694                       Planeta Maroccoli Syrah 2019
# 1415    2177753                      Marina Cvetić Chardonnay 2011
# 1405    1250539  Mas de Daumas Gassac Haut Vallée du Gassac Rou...
# 1852  174954957                 Domaine Lafage Miraflors Rosé 2023
# 1297  159626524  Antinori Castello della Sala San Giovanni dell...
# 1294  164927779                    Fantini Fantini Edizione Bianco
# 1738  150559449               Di Majo Norante Ramitello Rosso 2017
# 1730    2733999                 Feudi di San Gregorio Serpico 2012
# 1722  156155789                 Feudi di San Gregorio Taurasi 2018
# 1693  155956843                    Domaine Les Aurelles Aurel 2017
#
#      vintage_year vintage_price  vintage_ratings_average  \
# 1589         2019         62712                      4.1
# 1587         2016         55940                      4.1
# 1468         2021         17826                      4.1
# 1460         2017         34548                      4.1
# 1442         2010         97034                      4.1
# 1433         2019         32400                      4.1
# 1415         2011         97034                      4.1
# 1405         2003         81940                      4.1
# 1852         2023         16334                      4.0
# 1297         2019         21182                      4.1
# 1294         N.V.         28268                      4.1
# 1738         2017         23166                      4.0
# 1730         2012         92725                      4.0
# 1722         2018         35921                      4.0
# 1693         2017         96962                      4.0
#
#      vintage_ratings_count vintage_wine_id  \
# 1589                    32           85568
# 1587                    32         1470329
# 1468                   127         8705039
# 1460                   140         6492036
# 1442                   172         2526510
# 1433                   190            4994
# 1415                   220           93051
# 1405                   249           11079
# 1852                   101         1614560
# 1297                  1065            1693
# 1294                  1138         8532359
# 1738                   379         2029468
# 1730                   478            5098
# 1722                   527            5100
# 1693                   872         1449461
#
#                                       vintage_wine_name  \
# 1589                                      Balciana 2019
# 1587                                         Solen 2016
# 1468                                        Narses 2021
# 1460                              Tìade Etna Rosso 2017
# 1442                             Riserva Trebbiano 2010
# 1433                               Maroccoli Syrah 2019
# 1415                                    Chardonnay 2011
# 1405                   Haut Vallée du Gassac Rouge 2003
# 1852                                Miraflors Rosé 2023
# 1297  Castello della Sala San Giovanni della Sala Cl...
# 1294                       Fantini Edizione Bianco N.V.
# 1738                               Ramitello Rosso 2017
# 1730                                       Serpico 2012
# 1722                                       Taurasi 2018
# 1693                                         Aurel 2017
#
#              vintage_winery vintage_country  ... fizziness intensity  \
# 1589             Sartarelli           Italy  ...       NaN      3.61
# 1587   Domaine Les Aurelles          France  ...       NaN      3.92
# 1468             La Bollina           Italy  ...       NaN      4.60
# 1460  Marchese delle Saline           Italy  ...       NaN      4.60
# 1442          Marina Cvetić           Italy  ...       NaN      3.57
# 1433                Planeta           Italy  ...       NaN      4.60
# 1415          Marina Cvetić           Italy  ...       NaN      3.45
# 1405   Mas de Daumas Gassac          France  ...       NaN      3.85
# 1852         Domaine Lafage          France  ...       NaN      2.86
# 1297               Antinori           Italy  ...       NaN      2.98
# 1294                Fantini           Italy  ...       NaN      3.23
# 1738        Di Majo Norante           Italy  ...       NaN      4.00
# 1730  Feudi di San Gregorio           Italy  ...       NaN      4.67
# 1722  Feudi di San Gregorio           Italy  ...       NaN      4.57
# 1693   Domaine Les Aurelles          France  ...       NaN      3.88
#
#       sweetness  tannin        flavor  varietal_name  body_description  \
# 1589       2.42     NaN         earth          White     Medium-bodied
# 1587       1.79    3.48   black_fruit            Red       Full-bodied
# 1468       2.49    2.82   black_fruit            Red       Full-bodied
# 1460       2.00    3.01   black_fruit            Red       Full-bodied
# 1442       2.45     NaN           oak          White     Medium-bodied
# 1433       2.42    3.03           oak            Red       Full-bodied
# 1415       2.50     NaN           oak          White     Medium-bodied
# 1405       1.59    3.51           oak            Red       Full-bodied
# 1852       1.30     NaN     red_fruit           Rosé       Full-bodied
# 1297       2.29     NaN    tree_fruit          White     Medium-bodied
# 1294       2.35     NaN  citrus_fruit          White     Medium-bodied
# 1738       1.89    3.06   black_fruit            Red       Full-bodied
# 1730       2.37    3.20           oak            Red       Full-bodied
# 1722       2.19    3.35           oak            Red       Full-bodied
# 1693       1.52    3.38   black_fruit            Red       Full-bodied
#
#      acidity_description                                              foods  \
# 1589                High  Pasta, Vegetarian, Appetizers and snacks, Lean...
# 1587                High                                  Beef, Pasta, Veal
# 1468                High                                  Beef, Pasta, Lamb
# 1460                High                                  Beef, Pasta, Lamb
# 1442                High  Pasta, Vegetarian, Appetizers and snacks, Lean...
# 1433                High                                  Beef, Pasta, Lamb
# 1415                High  Pasta, Vegetarian, Appetizers and snacks, Lean...
# 1405                High                                  Beef, Pasta, Veal
# 1852                High  Pasta, Vegetarian, Appetizers and snacks, Lean...
# 1297                High  Pasta, Vegetarian, Appetizers and snacks, Lean...
# 1294                High  Pasta, Vegetarian, Appetizers and snacks, Lean...
# 1738                High                                  Beef, Pasta, Lamb
# 1730                High                                  Beef, Pasta, Lamb
# 1722                High                                  Beef, Pasta, Lamb
# 1693                High                                  Beef, Pasta, Veal
#
#      weighted_ratings
# 1589         4.213129
# 1587         4.213129
# 1468         4.184546
# 1460         4.181721
# 1442         4.175509
# 1433         4.172413
# 1415         4.167781
# 1405         4.163834
# 1852          4.16197
# 1297         4.124193
# 1294         4.122919
# 1738          4.09027
# 1730         4.077977
# 1722         4.073053
# 1693          4.05057
#
# [15 rows x 23 columns]

# %%
pd.options.display.float_format = '{:.0f}'.format
df['vintage_price'].describe()
# Out:
# count      2024
# mean     274546
# std      440186
# min       11859
# 25%       62622
# 50%      119726
# 75%      271702
# max     3428470
# Name: vintage_price, dtype: float64

# %%
df.columns
# Out:
# Index(['vintage_id', 'vintage_name', 'vintage_year', 'vintage_price',
#        'vintage_ratings_average', 'vintage_ratings_count', 'vintage_wine_id',
#        'vintage_wine_name', 'vintage_winery', 'vintage_country',
#        'vintage_region', 'vintage_wine_type', 'acidity', 'fizziness',
#        'intensity', 'sweetness', 'tannin', 'flavor', 'varietal_name',
#        'body_description', 'acidity_description', 'foods'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
# 회귀 모델 학습
X = df['acidity', 'fizziness','intensity', 'sweetness', 'tannin']
y = nu
model = LinearRegression()
model.fit(X, y)

# 회귀식의 계수와 절편 출력
coefficients = model.coef_
intercept = model.intercept_
