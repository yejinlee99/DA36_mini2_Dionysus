# %% [markdown]
# ## Vivino Webscraper
#
# #### Introduction:
# Vivino is a popular wine enthusiast website database of information about wine from around the world. This project is a proof of concept for scraping data from Vivino for the purposes of wine understanding the wine market in Spain. This proof of concept has some limitations. First, the list of wines scraped are not a complete and comprehensive view of Spanish wine, as wine culture in Spain has traditionally been that of small production and barrel sales. For this reason, many small wine producers are not included in Vivinos database and therefore not represented in the data. Second, the wines shown only include wines currently available for purchase. Lastly, as a consumer database, the results of ratings may not represent professional opinions and may be limited by the 5-star rating system due to its overly simplistic nature.

# %% [markdown]
# url = https://www.vivino.com/api/explore/explore?country_code=kr&currency_code=KRW&grape_filter=varietal&min_rating=1&order_by=ratings_average&order=desc&price_range_max=500000&price_range_min=0&page=1&language=en

# %%
import requests
import json
import pandas as pd
import time

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:89.0) Gecko/20100101 Firefox/89.0",
}

payload = {
        "country_codes": "kr",  
        "currency_code": "KRW",
        # "food_ids[]": [4],
        "grape_filter": "varietal",
        "min_rating": "1",
        "order_by": "ratings_average",
        "order": "desc",
        "page": 1,
        "price_range_max": "500000",
        "price_range_min": "0",
        "language": "en",
}


r = requests.get('https://www.vivino.com/api/explore/explore?',
                 params=payload, headers=headers)
n_matches = r.json()['explore_vintage']['records_matched']
matches = r.json()['explore_vintage']['matches']

# %%
n_matches
# Out:
# 3639

# %%
matches
# Out:
# [{'vintage': {'id': 177404982,
#    'seo_name': 'weingut-carl-loewen-eighteen-ninetysix-riesling-2023',
#    'name': 'Carl Loewen 1896 Riesling 2023',
#    'statistics': {'status': 'Normal',
#     'ratings_count': 115,
#     'ratings_average': 5,
#     'labels_count': 15,
#     'wine_ratings_count': 354,
#     'wine_ratings_average': 4.6,
#     'wine_status': ''},
#    'image': {'location': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pl_480x640.png',
#     'variations': {'bottle_large': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pb_x960.png',
#      'bottle_medium': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pb_x600.png',
#      'bottle_medium_square': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pb_600x600.png',
#      'bottle_small': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pb_x300.png',
#      'bottle_small_square': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pb_300x300.png',
#      'label': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pl_480x640.png',
#      'label_large': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pl_375x500.png',
#      'label_medium': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pl_150x200.png',
#      'label_medium_square': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pl_150x150.png',
#      'label_small_square': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pl_80x80.png',
#      'large': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pl_375x500.png',
#      'medium': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pl_150x200.png',
#      'medium_square': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pl_150x150.png',
#      'small_square': '//images.vivino.com/thumbs/Q8yn9Dn7SZa_V_IBeD51yw_pl_80x80.png'}},
#    'wine': {'id': 1945087,
#     'name': '1896 Riesling',
#     'seo_name': 'eighteen-ninetysix-riesling',
#     'type_id': 2,
#     'vintage_type': 0,
#     'is_natural': False,
#     'region': {'id': 545,
#      'name': 'Mosel',
#      'name_en': 'Mosel-Saar-Ruwer',
#      'seo_name': 'mosel-saar-ruwer',
#      'country': {'code': 'de',
#       'name': 'Germany',
#       'native_name': 'Deutschland',
#       'seo_name': 'germany',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 237,
#       'users_count': 2828467,
#       'wines_count': 174257,
#       'wineries_count': 13731,
#       'most_used_grapes': [{'id': 15,
#         'name': 'Riesling',
#         'seo_name': 'riesling',
#         'has_detailed_info': True,
#         'wines_count': 262136,
#         'parent_grape_id': None},
#        {'id': 299,
#         'name': 'Spätburgunder',
#         'seo_name': 'spatburgunder',
#         'has_detailed_info': False,
#         'wines_count': 50164,
#         'parent_grape_id': 14},
#        {'id': 355,
#         'name': 'Weissburgunder',
#         'seo_name': 'weissburgunder',
#         'has_detailed_info': False,
#         'wines_count': 33464,
#         'parent_grape_id': 36}]},
#      'class': {'typecast_map': {'background_image': {},
#        'class': {},
#        'location': {}}},
#      'background_image': {'location': '//images.vivino.com/regions/backgrounds/opJWUh7pR8u3jKqcy3D13g.jpg',
#       'variations': {'large': '//thumbs.vivino.com/region_backgrounds/opJWUh7pR8u3jKqcy3D13g_1280x760.jpg',
#        'medium': '//thumbs.vivino.com/region_backgrounds/opJWUh7pR8u3jKqcy3D13g_600x356.jpg'}}},
#     'winery': {'id': 3832,
#      'name': 'Carl Loewen',
#      'seo_name': 'weingut-carl-loewen',
#      'status': 0,
#      'background_image': None},
#     'taste': {'structure': {'acidity': 4.61,
#       'fizziness': None,
#       'intensity': 3.32,
#       'sweetness': 2.05,
#       'tannin': None,
#       'user_structure_count': 47,
#       'calculated_structure_count': 21},
#      'flavor': [{'group': 'tree_fruit',
#        'stats': {'count': 26, 'score': 4200},
#        'primary_keywords': [{'id': 9, 'name': 'apple', 'count': 8},
#         {'id': 315, 'name': 'pear', 'count': 7},
#         {'id': 271, 'name': 'melon', 'count': 6},
#         {'id': 11, 'name': 'apricot', 'count': 5},
#         {'id': 195, 'name': 'green apple', 'count': 4},
#         {'id': 310, 'name': 'peach', 'count': 3},
#         {'id': 78, 'name': 'cantaloupe', 'count': 2},
#         {'id': 458, 'name': 'yellow apple', 'count': 2},
#         {'id': 288, 'name': 'nectarine', 'count': 2},
#         {'id': 469, 'name': 'stone fruit', 'count': 1},
#         {'id': 460, 'name': 'yellow peach', 'count': 1},
#         {'id': 448, 'name': 'white peach', 'count': 1}]},
#       {'group': 'earth',
#        'stats': {'count': 23, 'score': 3740},
#        'primary_keywords': [{'id': 218, 'name': 'honey', 'count': 14},
#         {'id': 276, 'name': 'minerals', 'count': 9},
#         {'id': 377, 'name': 'salt', 'count': 4},
#         {'id': 398, 'name': 'stone', 'count': 4},
#         {'id': 325, 'name': 'petroleum', 'count': 3},
#         {'id': 181, 'name': 'ginger', 'count': 2},
#         {'id': 441, 'name': 'wax', 'count': 1},
#         {'id': 128, 'name': 'crushed rocks', 'count': 1}]},
#       {'group': 'citrus_fruit',
#        'stats': {'count': 19, 'score': 2400},
#        'primary_keywords': [{'id': 106, 'name': 'citrus', 'count': 9},
#         {'id': 252, 'name': 'lime', 'count': 6},
#         {'id': 243, 'name': 'lemon', 'count': 3},
#         {'id': 190, 'name': 'grapefruit', 'count': 3},
#         {'id': 298, 'name': 'orange', 'count': 2},
#         {'id': 246, 'name': 'lemon peel', 'count': 1}]},
#       {'group': 'microbio',
#        'stats': {'count': 14, 'score': 1767},
#        'primary_keywords': [{'id': 123, 'name': 'cream', 'count': 11},
#         {'id': 91, 'name': 'cheese', 'count': 2},
#         {'id': 457, 'name': 'yeast', 'count': 2},
#         {'id': 23, 'name': 'banana', 'count': 1},
#         {'id': 464, 'name': 'yogurt', 'count': 1},
#         {'id': 92, 'name': 'cheesy', 'count': 1}]},
#       {'group': 'tropical_fruit',
#        'stats': {'count': 8, 'score': 933},
#        'primary_keywords': [{'id': 306, 'name': 'passion fruit', 'count': 4},
#         {'id': 261, 'name': 'mango', 'count': 2},
#         {'id': 256, 'name': 'lychee', 'count': 2},
#         {'id': 329, 'name': 'pineapple', 'count': 1}],
#        'secondary_keywords': [{'id': 23, 'name': 'banana', 'count': 1}]},
#       {'group': 'spices',
#        'stats': {'count': 3, 'score': 185},
#        'primary_keywords': [{'id': 161, 'name': 'fennel', 'count': 1}],
#        'secondary_keywords': [{'id': 181, 'name': 'ginger', 'count': 2},
#         {'id': 138, 'name': 'dill', 'count': 1}]},
#       {'group': 'floral',
#        'stats': {'count': 3, 'score': 400},
#        'primary_keywords': [{'id': 230, 'name': 'jasmine', 'count': 1},
#         {'id': 322, 'name': 'perfume', 'count': 1},
#         {'id': 10, 'name': 'apple blossom', 'count': 1},
#         {'id': 436, 'name': 'violet', 'count': 1}]},
#       {'group': 'oak',
#        'stats': {'count': 3, 'score': 200},
#        'primary_keywords': [{'id': 117, 'name': 'coffee', 'count': 1},
#         {'id': 138, 'name': 'dill', 'count': 1}],
#        'secondary_keywords': [{'id': 62, 'name': 'brioche', 'count': 1}]},
#       {'group': 'vegetal',
#        'stats': {'count': 2, 'score': 200},
#        'primary_keywords': [{'id': 193, 'name': 'grass', 'count': 2}]},
#       {'group': 'non_oak',
#        'stats': {'count': 2, 'score': 75},
#        'primary_keywords': [{'id': 62, 'name': 'brioche', 'count': 1}],
#        'secondary_keywords': [{'id': 117, 'name': 'coffee', 'count': 1}]}]},
#     'statistics': None,
#     'style': {'id': 186,
#      'seo_name': 'german-riesling',
#      'regional_name': 'German',
#      'varietal_name': 'Riesling',
#      'name': 'German Riesling',
#      'background_image': None,
#      'image': None,
#      'description': "Riesling is without question Germany's favorite grape. Widely planted, though once derided, Riesling is the superstar of the white wine world at the moment.\n\nThere is a lot of scope for versatility with this sweet, viscous wine, though you can expect to get hints of tropical fruit, nectarine, melon and pineapple from a solid Riesling.\n\nThe grape originated in the Rhine region of Germany, and the best of them are said to grow along the banks of the Mosel River on the beautiful steep, south facing hills.\n\nThere are six categories of Riesling which indicate the ripeness of the grapes. Kabinett is considered “off-dry” and is a typically ripe grape. Spätlese is riper and therefor sweeter, and Auslese is even riper still. Beyond on that you have Beerenauslese, Trockenbeerenauslese and Eiswein (or ice wine), all getting sweeter, more viscous and more expensive.\n\nIt's a favorite in the food and beverage industry because of its willingness to play with a wide variety of foods, particular spicy dishes. The current Asian fusion boom is thought to have had a tremendous effect on Riesling's popularity.",
#      'blurb': None,
#      'interesting_facts': ['Riesling is grown all over the world and thrives in cool to warm climates.',
#       'Riesling is one of the few white wines that develops and improves with age.',
#       'There are an unusually high number of German Riesling producers that carry the prefix “Dr.”'],
#      'body': 2,
#      'body_description': 'Light-bodied',
#      'acidity': 3,
#      'acidity_description': 'High',
#      'country': {'code': 'de',
#       'name': 'Germany',
#       'native_name': 'Deutschland',
#       'seo_name': 'germany',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 237,
#       'users_count': 2828467,
#       'wines_count': 174257,
#       'wineries_count': 13731,
#       'most_used_grapes': [{'id': 15,
#         'name': 'Riesling',
#         'seo_name': 'riesling',
#         'has_detailed_info': True,
#         'wines_count': 262136,
#         'parent_grape_id': None},
#        {'id': 299,
#         'name': 'Spätburgunder',
#         'seo_name': 'spatburgunder',
#         'has_detailed_info': False,
#         'wines_count': 50164,
#         'parent_grape_id': 14},
#        {'id': 355,
#         'name': 'Weissburgunder',
#         'seo_name': 'weissburgunder',
#         'has_detailed_info': False,
#         'wines_count': 33464,
#         'parent_grape_id': 36}]},
#      'wine_type_id': 2,
#      'food': [{'id': 10,
#        'name': 'Pork',
#        'weight': 0.5,
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/10_pork.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/10_pork_932x810.png'}},
#        'seo_name': 'pork'},
#       {'id': 13,
#        'name': 'Shellfish',
#        'weight': 0.5,
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/13_shellfish.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/13_shellfish_932x810.png'}},
#        'seo_name': 'shellfish'},
#       {'id': 15,
#        'name': 'Spicy food',
#        'weight': 0,
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/15_spicyfood.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/15_spicyfood_932x810.png'}},
#        'seo_name': 'spicy-food'},
#       {'id': 20,
#        'name': 'Poultry',
#        'weight': 0.5,
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/20_chicken.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/20_chicken_932x810.png'}},
#        'seo_name': 'poultry'},
#       {'id': 41,
#        'name': 'Cured Meat',
#        'weight': 0,
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/41_curedmeat.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/41_curedmeat_932x810.png'}},
#        'seo_name': None}],
#      'grapes': [{'id': 15,
#        'name': 'Riesling',
#        'seo_name': 'riesling',
#        'has_detailed_info': True,
#        'wines_count': 262136,
#        'parent_grape_id': None}],
#      'region': None,
#      'parent_style_id': 785,
#      'hidden': False,
#      'statistics': {'wines_count': 40928, 'aggregated_wines_count': 40928},
#      'vintage_mask': '1<',
#      'baseline_structure': {'acidity': 5.0,
#       'fizziness': None,
#       'intensity': 3.0,
#       'sweetness': 1.0,
#       'tannin': None}},
#     'has_valid_ratings': False},
#    'year': 2023,
#    'grapes': None,
#    'has_valid_ratings': True},
#   'price': {'id': 36980675,
#    'merchant_id': 1943,
#    'amount': 82045,
#    'discounted_from': 0,
#    'discount_percent': None,
#    'type': 'ppc',
#    'sku': '',
#    'url': 'https://www.proidee.de/weine/weissweine/carl-loewen-1896-riesling-2023-mosel-deutschland-1-flasche-a-075-l',
#    'visibility': 1,
#    'bottle_type_id': 1,
#    'currency': {'code': 'KRW',
#     'name': 'South Korean Won',
#     'prefix': '₩',
#     'suffix': None},
#    'xms': 0,
#    'xmphs': False,
#    'price_group_id': None,
#    'vfm_score': 0,
#    'vfm_category': {'id': 0,
#     'title': 'Value Unavailable',
#     'subtitle': 'We’re still gathering data to determine this wine’s value score',
#     'barometer_position': None},
#    'bottle_type': {'id': 1,
#     'name': 'Bottle (0.75l)',
#     'short_name': 'bottle',
#     'short_name_plural': 'bottles',
#     'volume_ml': 750}},
#   'prices': [{'id': 36980675,
#     'merchant_id': 1943,
#     'amount': 82045,
#     'discounted_from': 0,
#     'discount_percent': None,
#     'type': 'ppc',
#     'sku': '',
#     'url': 'https://www.proidee.de/weine/weissweine/carl-loewen-1896-riesling-2023-mosel-deutschland-1-flasche-a-075-l',
#     'visibility': 1,
#     'bottle_type_id': 1,
#     'currency': {'code': 'KRW',
#      'name': 'South Korean Won',
#      'prefix': '₩',
#      'suffix': None},
#     'xms': 0,
#     'xmphs': False,
#     'price_group_id': None,
#     'vfm_score': 0,
#     'vfm_category': {'id': 0,
#      'title': 'Value Unavailable',
#      'subtitle': 'We’re still gathering data to determine this wine’s value score',
#      'barometer_position': None},
#     'bottle_type': {'id': 1,
#      'name': 'Bottle (0.75l)',
#      'short_name': 'bottle',
#      'short_name_plural': 'bottles',
#      'volume_ml': 750}}]},
#  {'vintage': {'id': 170413977,
#    'seo_name': 'domaines-ott-clos-mireille-rose-coeur-de-grain-2022',
#    'name': 'Domaines Ott Clos Mireille Rosé (Coeur de Grain) 2022',
#    'statistics': {'status': 'Normal',
#     'ratings_count': 581,
#     'ratings_average': 4.8,
#     'labels_count': 550,
#     'wine_ratings_count': 5580,
#     'wine_ratings_average': 4.3,
#     'wine_status': ''},
#    'image': {'location': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pl_480x640.png',
#     'variations': {'bottle_large': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pb_x960.png',
#      'bottle_medium': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pb_x600.png',
#      'bottle_medium_square': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pb_600x600.png',
#      'bottle_small': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pb_x300.png',
#      'bottle_small_square': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pb_300x300.png',
#      'label': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pl_480x640.png',
#      'label_large': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pl_375x500.png',
#      'label_medium': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pl_150x200.png',
#      'label_medium_square': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pl_150x150.png',
#      'label_small_square': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pl_80x80.png',
#      'large': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pl_375x500.png',
#      'medium': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pl_150x200.png',
#      'medium_square': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pl_150x150.png',
#      'small_square': '//images.vivino.com/thumbs/2J5LDR2GTQKcG98pAApYqA_pl_80x80.png'}},
#    'wine': {'id': 1382222,
#     'name': 'Clos Mireille Rosé (Coeur de Grain)',
#     'seo_name': 'clos-mireille-rose-coeur-de-grain',
#     'type_id': 4,
#     'vintage_type': 0,
#     'is_natural': False,
#     'region': {'id': 450,
#      'name': 'Côtes de Provence',
#      'name_en': '',
#      'seo_name': 'cotes-de-provence',
#      'country': {'code': 'fr',
#       'name': 'France',
#       'native_name': 'France',
#       'seo_name': 'france',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 1308,
#       'users_count': 6776969,
#       'wines_count': 440256,
#       'wineries_count': 68417,
#       'most_used_grapes': [{'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 572334,
#         'parent_grape_id': None},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 604208,
#         'parent_grape_id': None},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 566719,
#         'parent_grape_id': None}]},
#      'class': {'typecast_map': {'background_image': {},
#        'class': {},
#        'location': {}}},
#      'background_image': {'location': '//images.vivino.com/regions/backgrounds/f6SgQnCgSAGVBlY9MIxwZw.jpg',
#       'variations': {'large': '//thumbs.vivino.com/region_backgrounds/f6SgQnCgSAGVBlY9MIxwZw_1280x760.jpg',
#        'medium': '//thumbs.vivino.com/region_backgrounds/f6SgQnCgSAGVBlY9MIxwZw_600x356.jpg'}}},
#     'winery': {'id': 2838,
#      'name': 'Domaines Ott',
#      'seo_name': 'domaines-ott',
#      'status': 0,
#      'background_image': None},
#     'taste': {'structure': {'acidity': 3.77,
#       'fizziness': None,
#       'intensity': 2.5,
#       'sweetness': 1.33,
#       'tannin': None,
#       'user_structure_count': 117,
#       'calculated_structure_count': 206},
#      'flavor': [{'group': 'citrus_fruit',
#        'stats': {'count': 110, 'score': 15600},
#        'primary_keywords': [{'id': 106, 'name': 'citrus', 'count': 57},
#         {'id': 190, 'name': 'grapefruit', 'count': 35},
#         {'id': 243, 'name': 'lemon', 'count': 24},
#         {'id': 298, 'name': 'orange', 'count': 9},
#         {'id': 300, 'name': 'orange peel', 'count': 5},
#         {'id': 109, 'name': 'citrus zest', 'count': 5},
#         {'id': 411, 'name': 'tangerine', 'count': 4},
#         {'id': 252, 'name': 'lime', 'count': 3},
#         {'id': 260, 'name': 'mandarin orange', 'count': 2},
#         {'id': 302, 'name': 'orange zest', 'count': 2},
#         {'id': 330, 'name': 'pink grapefruit', 'count': 2},
#         {'id': 254, 'name': 'lime zest', 'count': 1},
#         {'id': 301, 'name': 'orange rind', 'count': 1},
#         {'id': 246, 'name': 'lemon peel', 'count': 1},
#         {'id': 191, 'name': 'grapefruit pith', 'count': 1},
#         {'id': 274, 'name': 'meyer lemon', 'count': 1},
#         {'id': 54, 'name': 'blood orange', 'count': 1},
#         {'id': 248, 'name': 'lemon zest', 'count': 1},
#         {'id': 337, 'name': 'pomello', 'count': 1}]},
#       {'group': 'tree_fruit',
#        'stats': {'count': 104, 'score': 14100},
#        'primary_keywords': [{'id': 310, 'name': 'peach', 'count': 53},
#         {'id': 271, 'name': 'melon', 'count': 24},
#         {'id': 448, 'name': 'white peach', 'count': 12},
#         {'id': 11, 'name': 'apricot', 'count': 12},
#         {'id': 315, 'name': 'pear', 'count': 11},
#         {'id': 288, 'name': 'nectarine', 'count': 10},
#         {'id': 9, 'name': 'apple', 'count': 8},
#         {'id': 469, 'name': 'stone fruit', 'count': 6},
#         {'id': 195, 'name': 'green apple', 'count': 3},
#         {'id': 458, 'name': 'yellow apple', 'count': 1},
#         {'id': 461, 'name': 'yellow plum', 'count': 1}]},
#       {'group': 'red_fruit',
#        'stats': {'count': 99, 'score': 11900},
#        'primary_keywords': [{'id': 400, 'name': 'strawberry', 'count': 78},
#         {'id': 348, 'name': 'raspberry', 'count': 16},
#         {'id': 354, 'name': 'red fruit', 'count': 5},
#         {'id': 93, 'name': 'cherry', 'count': 4},
#         {'id': 122, 'name': 'cranberry', 'count': 4},
#         {'id': 452, 'name': 'wild strawberry', 'count': 3},
#         {'id': 440, 'name': 'watermelon', 'count': 2},
#         {'id': 171, 'name': 'fresh strawberry', 'count': 2},
#         {'id': 352, 'name': 'red cherry', 'count': 2},
#         {'id': 353, 'name': 'red currant', 'count': 2},
#         {'id': 336, 'name': 'pomegranate', 'count': 1}]},
#       {'group': 'earth',
#        'stats': {'count': 71, 'score': 7534},
#        'primary_keywords': [{'id': 276, 'name': 'minerals', 'count': 33},
#         {'id': 376, 'name': 'saline', 'count': 11},
#         {'id': 398, 'name': 'stone', 'count': 10},
#         {'id': 218, 'name': 'honey', 'count': 10},
#         {'id': 85, 'name': 'chalk', 'count': 3},
#         {'id': 377, 'name': 'salt', 'count': 2},
#         {'id': 383, 'name': 'slate', 'count': 2},
#         {'id': 242, 'name': 'leather', 'count': 1},
#         {'id': 384, 'name': 'smoke', 'count': 1},
#         {'id': 164, 'name': 'flint', 'count': 1},
#         {'id': 160, 'name': 'exotic spice', 'count': 1}],
#        'secondary_keywords': [{'id': 6, 'name': 'almond', 'count': 3},
#         {'id': 381, 'name': 'savory', 'count': 1}]},
#       {'group': 'tropical_fruit',
#        'stats': {'count': 21, 'score': 2500},
#        'primary_keywords': [{'id': 261, 'name': 'mango', 'count': 13},
#         {'id': 306, 'name': 'passion fruit', 'count': 6},
#         {'id': 428, 'name': 'tropical', 'count': 3},
#         {'id': 329, 'name': 'pineapple', 'count': 3}]},
#       {'group': 'microbio',
#        'stats': {'count': 20, 'score': 1562},
#        'primary_keywords': [{'id': 123, 'name': 'cream', 'count': 9},
#         {'id': 295, 'name': 'oil', 'count': 2},
#         {'id': 457, 'name': 'yeast', 'count': 1},
#         {'id': 91, 'name': 'cheese', 'count': 1},
#         {'id': 129, 'name': 'curd', 'count': 1}],
#        'secondary_keywords': [{'id': 70, 'name': 'butter', 'count': 3},
#         {'id': 6, 'name': 'almond', 'count': 3},
#         {'id': 417, 'name': 'toast', 'count': 1}]},
#       {'group': 'oak',
#        'stats': {'count': 18, 'score': 1285},
#        'primary_keywords': [{'id': 434, 'name': 'vanilla', 'count': 5},
#         {'id': 70, 'name': 'butter', 'count': 3},
#         {'id': 292, 'name': 'oak', 'count': 2},
#         {'id': 117, 'name': 'coffee', 'count': 1},
#         {'id': 101, 'name': 'chocolate', 'count': 1},
#         {'id': 79, 'name': 'caramel', 'count': 1}],
#        'secondary_keywords': [{'id': 6, 'name': 'almond', 'count': 3},
#         {'id': 105, 'name': 'cinnamon', 'count': 2},
#         {'id': 242, 'name': 'leather', 'count': 1},
#         {'id': 62, 'name': 'brioche', 'count': 1},
#         {'id': 384, 'name': 'smoke', 'count': 1}]},
#       {'group': 'spices',
#        'stats': {'count': 17, 'score': 1057},
#        'primary_keywords': [{'id': 161, 'name': 'fennel', 'count': 2},
#         {'id': 449, 'name': 'white pepper', 'count': 2},
#         {'id': 416, 'name': 'thyme', 'count': 2},
#         {'id': 105, 'name': 'cinnamon', 'count': 2},
#         {'id': 375, 'name': 'sage', 'count': 2},
#         {'id': 159, 'name': 'eucalyptus', 'count': 1},
#         {'id': 381, 'name': 'savory', 'count': 1}],
#        'secondary_keywords': [{'id': 434, 'name': 'vanilla', 'count': 5}]},
#       {'group': 'vegetal',
#        'stats': {'count': 14, 'score': 1055},
#        'primary_keywords': [{'id': 193, 'name': 'grass', 'count': 4},
#         {'id': 212, 'name': 'hay', 'count': 3},
#         {'id': 399, 'name': 'straw', 'count': 2},
#         {'id': 359, 'name': 'rhubarb', 'count': 1}],
#        'secondary_keywords': [{'id': 6, 'name': 'almond', 'count': 3},
#         {'id': 381, 'name': 'savory', 'count': 1}]},
#       {'group': 'non_oak',
#        'stats': {'count': 13, 'score': 482},
#        'primary_keywords': [{'id': 6, 'name': 'almond', 'count': 3},
#         {'id': 417, 'name': 'toast', 'count': 1},
#         {'id': 62, 'name': 'brioche', 'count': 1},
#         {'id': 291, 'name': 'nutty', 'count': 1}],
#        'secondary_keywords': [{'id': 434, 'name': 'vanilla', 'count': 5},
#         {'id': 105, 'name': 'cinnamon', 'count': 2},
#         {'id': 117, 'name': 'coffee', 'count': 1},
#         {'id': 384, 'name': 'smoke', 'count': 1},
#         {'id': 79, 'name': 'caramel', 'count': 1}]},
#       {'group': 'floral',
#        'stats': {'count': 10, 'score': 925},
#        'primary_keywords': [{'id': 371, 'name': 'rose petal', 'count': 3},
#         {'id': 322, 'name': 'perfume', 'count': 2},
#         {'id': 299, 'name': 'orange blossom', 'count': 2},
#         {'id': 241, 'name': 'lavender', 'count': 2}],
#        'secondary_keywords': [{'id': 381, 'name': 'savory', 'count': 1}]},
#       {'group': 'dried_fruit',
#        'stats': {'count': 3, 'score': 289},
#        'primary_keywords': [{'id': 341, 'name': 'prune', 'count': 1},
#         {'id': 347, 'name': 'raisin', 'count': 1},
#         {'id': 140, 'name': 'dried apricot', 'count': 1}]},
#       {'group': 'black_fruit',
#        'stats': {'count': 1, 'score': 11},
#        'secondary_keywords': [{'id': 341, 'name': 'prune', 'count': 1}]}]},
#     'statistics': None,
#     'style': {'id': 173,
#      'seo_name': 'provence-rose',
#      'regional_name': 'Provence',
#      'varietal_name': 'Rosé',
#      'name': 'Provence Rosé',
#      'background_image': None,
#      'image': None,
#      'description': "No summer afternoon is complete without a little bit of the pale pink/orange wines from Provence.\n\nThese light and crisp roses have just the slightest touches of bright berry flavors and can complement a meal perfectly or be delightful on their own.\n\nThe dry, refreshing, pink wines of Provence may not be complicated or heady, but they are certainly lovely. These brightly flavored, yet pale colored wines are full of crisp acidity with light touches of tart red berries and citrus fruit.\n\nThese wines may not be serious, but you can't drink serious wines all of the time! Current trends are making these wines ridiculously popular, and for good reason.\n\nThey are the perfect summer wine and can make any light afternoon meal even better with their liveliness and pretty fruit. These are much lighter than most California roses, but are typically much fresher and sharper.",
#      'blurb': None,
#      'interesting_facts': ['In Provence, almost 90% of the wine production is attributed to rose.',
#       'Brad Pitt and Angelina Jolie are part owners of a Provencal Rose called Miraval.',
#       'The light, pink wines of the area have been around since even before the Roman control in the 2nd Century BC!',
#       'There are 13 different grape varieties allowed in Cotes de Provence.',
#       'Provence has a Mediterranean climate.'],
#      'body': 3,
#      'body_description': 'Medium-bodied',
#      'acidity': 3,
#      'acidity_description': 'High',
#      'country': {'code': 'fr',
#       'name': 'France',
#       'native_name': 'France',
#       'seo_name': 'france',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 1308,
#       'users_count': 6776969,
#       'wines_count': 440256,
#       'wineries_count': 68417,
#       'most_used_grapes': [{'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 572334,
#         'parent_grape_id': None},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 604208,
#         'parent_grape_id': None},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 566719,
#         'parent_grape_id': None}]},
#      'wine_type_id': 4,
#      'food': [{'id': 10,
#        'name': 'Pork',
#        'weight': 0.5,
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/10_pork.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/10_pork_932x810.png'}},
#        'seo_name': 'pork'},
#       {'id': 13,
#        'name': 'Shellfish',
#        'weight': 0.5,
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/13_shellfish.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/13_shellfish_932x810.png'}},
#        'seo_name': 'shellfish'},
#       {'id': 19,
#        'name': 'Vegetarian',
#        'weight': 0.5,
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/19_vegetarian.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/19_vegetarian_932x810.png'}},
#        'seo_name': 'vegetarian'},
#       {'id': 20,
#        'name': 'Poultry',
#        'weight': 0.5,
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/20_chicken.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/20_chicken_932x810.png'}},
#        'seo_name': 'poultry'}],
#      'grapes': [{'id': 1,
#        'name': 'Shiraz/Syrah',
#        'seo_name': 'shiraz-syrah',
#        'has_detailed_info': True,
#        'wines_count': 551112,
#        'parent_grape_id': None},
#       {'id': 8,
#        'name': 'Grenache',
#        'seo_name': 'grenache-noir',
#        'has_detailed_info': True,
#        'wines_count': 240002,
#        'parent_grape_id': None},
#       {'id': 75,
#        'name': 'Cinsault',
#        'seo_name': 'cinsault',
#        'has_detailed_info': False,
#        'wines_count': 49347,
#        'parent_grape_id': None}],
#      'region': {'id': 449,
#       'name': 'Provence',
#       'name_en': '',
#       'seo_name': 'provence',
#       'country': {'code': 'fr',
#        'name': 'France',
#        'native_name': 'France',
#        'seo_name': 'france',
#        'currency': {'code': 'EUR',
#         'name': 'Euros',
#         'prefix': '€',
#         'suffix': None},
#        'regions_count': 1308,
#        'users_count': 6776969,
#        'wines_count': 440256,
#        'wineries_count': 68417,
#        'most_used_grapes': [{'id': 14,
#          'name': 'Pinot Noir',
#          'seo_name': 'pinot-noir',
#          'has_detailed_info': True,
#          'wines_count': 572334,
#          'parent_grape_id': None},
#         {'id': 5,
#          'name': 'Chardonnay',
#          'seo_name': 'chardonnay',
#          'has_detailed_info': True,
#          'wines_count': 604208,
#          'parent_grape_id': None},
#         {'id': 10,
#          'name': 'Merlot',
#          'seo_name': 'merlot',
#          'has_detailed_info': True,
#          'wines_count': 566719,
#          'parent_grape_id': None}]},
#       'parent_id': None,
#       'background_image': {'location': '//images.vivino.com/regions/backgrounds/9bPQ0KjlSJuEG2HZpwyhQg.jpg',
#        'variations': {'large': '//thumbs.vivino.com/region_backgrounds/9bPQ0KjlSJuEG2HZpwyhQg_1280x760.jpg',
#         'medium': '//thumbs.vivino.com/region_backgrounds/9bPQ0KjlSJuEG2HZpwyhQg_600x356.jpg'}},
#       'statistics': {'wineries_count': 1682,
#        'wines_count': 10244,
#        'sub_regions_count': 9,
#        'parent_regions_count': 0}},
#      'parent_style_id': 782,
#      'hidden': False,
#      'statistics': {'wines_count': 4787, 'aggregated_wines_count': 4787},
#      'vintage_mask': '1<',
#      'baseline_structure': {'acidity': 4.0,
#       'fizziness': None,
#       'intensity': 2.5,
#       'sweetness': 1.0,
#       'tannin': None}},
#     'has_valid_ratings': False},
#    'year': 2022,
#    'grapes': None,
#    'has_valid_ratings': True},
#   'price': {'id': 34173848,
#    'merchant_id': 1943,
#    'amount': 59594,
#    'discounted_from': 0,
#    'discount_percent': None,
#    'type': 'ppc',
#    'sku': '',
#    'url': 'https://www.proidee.de/weine/roseweine/domaine-ott-clos-mireille-rose-2022-cotes-de-provence-aoc-cru-classe-frankreich-1-flasche-a-075-l',
#    'visibility': 1,
#    'bottle_type_id': 1,
#    'currency': {'code': 'KRW',
#     'name': 'South Korean Won',
#     'prefix': '₩',
#     'suffix': None},
#    'xms': 0,
#    'xmphs': False,
#    'price_group_id': None,
#    'vfm_score': 0,
#    'vfm_category': {'id': 0,
#     'title': 'Value Unavailable',
#     'subtitle': 'We’re still gathering data to determine this wine’s value score',
#     'barometer_position': None},
#    'bottle_type': {'id': 1,
#     'name': 'Bottle (0.75l)',
#     'short_name': 'bottle',
#     'short_name_plural': 'bottles',
#     'volume_ml': 750}},
#   'prices': [{'id': 34173848,
#     'merchant_id': 1943,
#     'amount': 59594,
#     'discounted_from': 0,
#     'discount_percent': None,
#     'type': 'ppc',
#     'sku': '',
#     'url': 'https://www.proidee.de/weine/roseweine/domaine-ott-clos-mireille-rose-2022-cotes-de-provence-aoc-cru-classe-frankreich-1-flasche-a-075-l',
#     'visibility': 1,
#     'bottle_type_id': 1,
#     'currency': {'code': 'KRW',
#      'name': 'South Korean Won',
#      'prefix': '₩',
#      'suffix': None},
#     'xms': 0,
#     'xmphs': False,
#     'price_group_id': None,
#     'vfm_score': 0,
#     'vfm_category': {'id': 0,
#      'title': 'Value Unavailable',
#      'subtitle': 'We’re still gathering data to determine this wine’s value score',
#      'barometer_position': None},
#     'bottle_type': {'id': 1,
#      'name': 'Bottle (0.75l)',
#      'short_name': 'bottle',
#      'short_name_plural': 'bottles',
#      'volume_ml': 750}}]},
#  {'vintage': {'id': 1688597,
#    'seo_name': 'krug-clos-du-mesnil-2000',
#    'name': 'Krug Clos du Mesnil 2000',
#    'statistics': {'status': 'Normal',
#     'ratings_count': 347,
#     'ratings_average': 4.8,
#     'labels_count': 1189,
#     'wine_ratings_count': 2760,
#     'wine_ratings_average': 4.7,
#     'wine_status': ''},
#    'image': {'location': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pl_480x640.png',
#     'variations': {'bottle_large': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pb_x960.png',
#      'bottle_medium': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pb_x600.png',
#      'bottle_medium_square': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pb_600x600.png',
#      'bottle_small': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pb_x300.png',
#      'bottle_small_square': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pb_300x300.png',
#      'label': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pl_480x640.png',
#      'label_large': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pl_375x500.png',
#      'label_medium': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pl_150x200.png',
#      'label_medium_square': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pl_150x150.png',
#      'label_small_square': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pl_80x80.png',
#      'large': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pl_375x500.png',
#      'medium': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pl_150x200.png',
#      'medium_square': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pl_150x150.png',
#      'small_square': '//images.vivino.com/thumbs/xtWMPmF6RtKFoWz3kpxz4Q_pl_80x80.png'}},
#    'wine': {'id': 79635,
#     'name': 'Clos du Mesnil',
#     'seo_name': 'clos-du-mesnil',
#     'type_id': 3,
#     'vintage_type': 0,
#     'is_natural': False,
#     'region': {'id': 409,
#      'name': 'Champagne',
#      'name_en': '',
#      'seo_name': 'champagne',
#      'country': {'code': 'fr',
#       'name': 'France',
#       'native_name': 'France',
#       'seo_name': 'france',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 1308,
#       'users_count': 6776969,
#       'wines_count': 440256,
#       'wineries_count': 68417,
#       'most_used_grapes': [{'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 572334,
#         'parent_grape_id': None},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 604208,
#         'parent_grape_id': None},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 566719,
#         'parent_grape_id': None}]},
#      'class': {'typecast_map': {'background_image': {},
#        'class': {},
#        'location': {}}},
#      'background_image': {'location': '//images.vivino.com/regions/backgrounds/pDAYNERYTeqN3vazOSIscw.jpg',
#       'variations': {'large': '//thumbs.vivino.com/region_backgrounds/pDAYNERYTeqN3vazOSIscw_1280x760.jpg',
#        'medium': '//thumbs.vivino.com/region_backgrounds/pDAYNERYTeqN3vazOSIscw_600x356.jpg'}}},
#     'winery': {'id': 1337,
#      'name': 'Krug',
#      'seo_name': 'krug',
#      'status': 0,
#      'background_image': {'location': '//images.vivino.com/wineries/backgrounds/f9LMytQ8R5u4uIc75aJQSg.jpeg',
#       'variations': {'large': '//thumbs.vivino.com/winery_backgrounds/f9LMytQ8R5u4uIc75aJQSg_2560x1520.jpeg',
#        'medium': '//thumbs.vivino.com/winery_backgrounds/f9LMytQ8R5u4uIc75aJQSg_1280x760.jpeg',
#        'small': '//thumbs.vivino.com/winery_backgrounds/f9LMytQ8R5u4uIc75aJQSg_600x356.jpeg'}}},
#     'taste': {'structure': {'acidity': 4.54,
#       'fizziness': 4.22,
#       'intensity': 3.97,
#       'sweetness': None,
#       'tannin': None,
#       'user_structure_count': 373,
#       'calculated_structure_count': 141},
#      'flavor': [{'group': 'non_oak',
#        'stats': {'count': 119, 'score': 10321},
#        'primary_keywords': [{'id': 62, 'name': 'brioche', 'count': 44},
#         {'id': 417, 'name': 'toast', 'count': 33},
#         {'id': 6, 'name': 'almond', 'count': 19},
#         {'id': 35, 'name': 'biscuit', 'count': 15},
#         {'id': 213, 'name': 'hazelnut', 'count': 13},
#         {'id': 291, 'name': 'nutty', 'count': 5},
#         {'id': 267, 'name': 'marzipan', 'count': 4},
#         {'id': 362, 'name': 'roasted almond', 'count': 3},
#         {'id': 418, 'name': 'toasted almond', 'count': 3},
#         {'id': 438, 'name': 'walnut', 'count': 2},
#         {'id': 439, 'name': 'walnut oil', 'count': 1},
#         {'id': 421, 'name': 'toasted nuts', 'count': 1},
#         {'id': 145, 'name': 'dried fig', 'count': 1},
#         {'id': 363, 'name': 'roasted hazelnut', 'count': 1}],
#        'secondary_keywords': [{'id': 79, 'name': 'caramel', 'count': 14},
#         {'id': 434, 'name': 'vanilla', 'count': 12},
#         {'id': 117, 'name': 'coffee', 'count': 9},
#         {'id': 384, 'name': 'smoke', 'count': 8}]},
#       {'group': 'earth',
#        'stats': {'count': 106, 'score': 12839},
#        'primary_keywords': [{'id': 218, 'name': 'honey', 'count': 42},
#         {'id': 276, 'name': 'minerals', 'count': 41},
#         {'id': 430, 'name': 'truffle', 'count': 9},
#         {'id': 85, 'name': 'chalk', 'count': 8},
#         {'id': 384, 'name': 'smoke', 'count': 8},
#         {'id': 181, 'name': 'ginger', 'count': 6},
#         {'id': 376, 'name': 'saline', 'count': 4},
#         {'id': 398, 'name': 'stone', 'count': 3},
#         {'id': 164, 'name': 'flint', 'count': 3},
#         {'id': 219, 'name': 'honeycomb', 'count': 2},
#         {'id': 382, 'name': 'seashell', 'count': 1},
#         {'id': 377, 'name': 'salt', 'count': 1},
#         {'id': 86, 'name': 'chalk dust', 'count': 1},
#         {'id': 156, 'name': 'earthy', 'count': 1},
#         {'id': 47, 'name': 'black truffle', 'count': 1}],
#        'secondary_keywords': [{'id': 6, 'name': 'almond', 'count': 19},
#         {'id': 267, 'name': 'marzipan', 'count': 4}]},
#       {'group': 'oak',
#        'stats': {'count': 104, 'score': 9720},
#        'primary_keywords': [{'id': 70, 'name': 'butter', 'count': 16},
#         {'id': 79, 'name': 'caramel', 'count': 14},
#         {'id': 434, 'name': 'vanilla', 'count': 12},
#         {'id': 292, 'name': 'oak', 'count': 9},
#         {'id': 117, 'name': 'coffee', 'count': 9},
#         {'id': 424, 'name': 'toffee', 'count': 6},
#         {'id': 101, 'name': 'chocolate', 'count': 4},
#         {'id': 308, 'name': 'pastry', 'count': 2},
#         {'id': 115, 'name': 'coconut', 'count': 2},
#         {'id': 103, 'name': 'cigar', 'count': 1},
#         {'id': 379, 'name': 'sandalwood', 'count': 1},
#         {'id': 257, 'name': 'macadamia nut', 'count': 1}],
#        'secondary_keywords': [{'id': 62, 'name': 'brioche', 'count': 44},
#         {'id': 6, 'name': 'almond', 'count': 19},
#         {'id': 213, 'name': 'hazelnut', 'count': 13},
#         {'id': 384, 'name': 'smoke', 'count': 8},
#         {'id': 267, 'name': 'marzipan', 'count': 4},
#         {'id': 244, 'name': 'lemon curd', 'count': 4},
#         {'id': 168, 'name': 'fresh bread', 'count': 1}]},
#       {'group': 'citrus_fruit',
#        'stats': {'count': 101, 'score': 13600},
#        'primary_keywords': [{'id': 106, 'name': 'citrus', 'count': 62},
#         {'id': 243, 'name': 'lemon', 'count': 25},
#         {'id': 252, 'name': 'lime', 'count': 12},
#         {'id': 298, 'name': 'orange', 'count': 9},
#         {'id': 246, 'name': 'lemon peel', 'count': 6},
#         {'id': 190, 'name': 'grapefruit', 'count': 6},
#         {'id': 248, 'name': 'lemon zest', 'count': 5},
#         {'id': 254, 'name': 'lime zest', 'count': 3},
#         {'id': 300, 'name': 'orange peel', 'count': 3},
#         {'id': 266, 'name': 'marmalade', 'count': 2},
#         {'id': 411, 'name': 'tangerine', 'count': 1},
#         {'id': 54, 'name': 'blood orange', 'count': 1}],
#        'secondary_keywords': [{'id': 244, 'name': 'lemon curd', 'count': 4}]},
#       {'group': 'microbio',
#        'stats': {'count': 87, 'score': 5579},
#        'primary_keywords': [{'id': 123, 'name': 'cream', 'count': 16},
#         {'id': 457, 'name': 'yeast', 'count': 5},
#         {'id': 419, 'name': 'toasted bread', 'count': 4},
#         {'id': 244, 'name': 'lemon curd', 'count': 4},
#         {'id': 23, 'name': 'banana', 'count': 3},
#         {'id': 295, 'name': 'oil', 'count': 2},
#         {'id': 168, 'name': 'fresh bread', 'count': 1},
#         {'id': 91, 'name': 'cheese', 'count': 1},
#         {'id': 92, 'name': 'cheesy', 'count': 1},
#         {'id': 129, 'name': 'curd', 'count': 1}],
#        'secondary_keywords': [{'id': 417, 'name': 'toast', 'count': 33},
#         {'id': 6, 'name': 'almond', 'count': 19},
#         {'id': 70, 'name': 'butter', 'count': 16},
#         {'id': 430, 'name': 'truffle', 'count': 9},
#         {'id': 424, 'name': 'toffee', 'count': 6}]},
#       {'group': 'tree_fruit',
#        'stats': {'count': 65, 'score': 8500},
#        'primary_keywords': [{'id': 9, 'name': 'apple', 'count': 20},
#         {'id': 195, 'name': 'green apple', 'count': 19},
#         {'id': 310, 'name': 'peach', 'count': 15},
#         {'id': 11, 'name': 'apricot', 'count': 9},
#         {'id': 315, 'name': 'pear', 'count': 6},
#         {'id': 271, 'name': 'melon', 'count': 4},
#         {'id': 458, 'name': 'yellow apple', 'count': 3},
#         {'id': 448, 'name': 'white peach', 'count': 3},
#         {'id': 19, 'name': 'baked apple', 'count': 2},
#         {'id': 288, 'name': 'nectarine', 'count': 1},
#         {'id': 323, 'name': 'persimmon', 'count': 1},
#         {'id': 343, 'name': 'quince', 'count': 1},
#         {'id': 469, 'name': 'stone fruit', 'count': 1}]},
#       {'group': 'spices',
#        'stats': {'count': 28, 'score': 1652},
#        'primary_keywords': [{'id': 449, 'name': 'white pepper', 'count': 5},
#         {'id': 182, 'name': 'gingerbread', 'count': 3},
#         {'id': 75, 'name': 'candied ginger', 'count': 2},
#         {'id': 159, 'name': 'eucalyptus', 'count': 1},
#         {'id': 277, 'name': 'mint', 'count': 1},
#         {'id': 320, 'name': 'pepper', 'count': 1},
#         {'id': 40, 'name': 'black licorice', 'count': 1}],
#        'secondary_keywords': [{'id': 434, 'name': 'vanilla', 'count': 12},
#         {'id': 181, 'name': 'ginger', 'count': 6}]},
#       {'group': 'vegetal',
#        'stats': {'count': 23, 'score': 690},
#        'primary_keywords': [{'id': 212, 'name': 'hay', 'count': 2},
#         {'id': 399, 'name': 'straw', 'count': 2},
#         {'id': 185, 'name': 'gooseberry', 'count': 1}],
#        'secondary_keywords': [{'id': 6, 'name': 'almond', 'count': 19}]},
#       {'group': 'tropical_fruit',
#        'stats': {'count': 15, 'score': 1499},
#        'primary_keywords': [{'id': 428, 'name': 'tropical', 'count': 7},
#         {'id': 329, 'name': 'pineapple', 'count': 4},
#         {'id': 203, 'name': 'green papaya', 'count': 2},
#         {'id': 208, 'name': 'grilled pineapple', 'count': 1}],
#        'secondary_keywords': [{'id': 23, 'name': 'banana', 'count': 3}]},
#       {'group': 'floral',
#        'stats': {'count': 11, 'score': 1200},
#        'primary_keywords': [{'id': 2, 'name': 'acacia', 'count': 5},
#         {'id': 221, 'name': 'honeysuckle', 'count': 2},
#         {'id': 87, 'name': 'chamomile', 'count': 2},
#         {'id': 107, 'name': 'citrus blossom', 'count': 1},
#         {'id': 146, 'name': 'dried flowers', 'count': 1},
#         {'id': 133, 'name': 'dandelion', 'count': 1}]},
#       {'group': 'dried_fruit',
#        'stats': {'count': 8, 'score': 872},
#        'primary_keywords': [{'id': 341, 'name': 'prune', 'count': 4},
#         {'id': 147, 'name': 'dried fruit', 'count': 2},
#         {'id': 347, 'name': 'raisin', 'count': 2},
#         {'id': 140, 'name': 'dried apricot', 'count': 1}],
#        'secondary_keywords': [{'id': 229, 'name': 'jam', 'count': 1}]},
#       {'group': 'black_fruit',
#        'stats': {'count': 6, 'score': 212},
#        'primary_keywords': [{'id': 229, 'name': 'jam', 'count': 1},
#         {'id': 334, 'name': 'plum', 'count': 1}],
#        'secondary_keywords': [{'id': 341, 'name': 'prune', 'count': 4}]},
#       {'group': 'red_fruit',
#        'stats': {'count': 2, 'score': 116},
#        'primary_keywords': [{'id': 400, 'name': 'strawberry', 'count': 1}],
#        'secondary_keywords': [{'id': 229, 'name': 'jam', 'count': 1}]}]},
#     'statistics': None,
#     'style': {'id': 50,
#      'seo_name': 'french-champagne',
#      'regional_name': 'French',
#      'varietal_name': 'Champagne',
#      'name': 'French Champagne',
#      'background_image': None,
#      'image': None,
#      'description': "While there are many sparkling wine regions around the globe, only Champagne from the Champagne appellation in France can be labeled as such.\xa0\n\nChampagne has long been the wine of choice to celebrate special occasions, and its reputation as a luxury beverage has been intact since the Romans established vineyards in Reims in the 5th century (that's a really long time ago).\xa0\n\nSparkling Champagne wasn't discovered until the 16th century, by accident, by the Benedictine Monks. Early vintages of Champagne were dubbed “the devil's wine” because the bottles tended to explode. Improvements to both bottle and cork developed over hundreds of years.\xa0\n\nChampagne is mainly made from a blend of Chardonnay, Pinot Noir, and Pinot Meunier grapes, and most of it is produced as a non-vintage wine, meaning that it's a blend of several vintages. Generally speaking, non-vintage Champagne is fantastic, and tends to be less expensive than vintage Champagne—this is because a vintage year is only declared when growing conditions are especially favorable.\xa0\n\nThe convivial nature of Champagne is due in part to how it's made. Following primary fermentation and bottling, a secondary alcoholic fermentation is induced in the bottle, which is achieved by the addition of yeast and rock sugar. The bubbles we love so much are a natural byproduct of this magical secondary fermentation, in the form of carbon dioxide.",
#      'blurb': 'Premium sparkling wine',
#      'interesting_facts': ['Champagne corks are under so much pressure that a flying cork can reach speeds of 50 miles (80km) per hour. ',
#       'Champagne goes great with comfort foods like mac & cheese, fried chicken and buttered popcorn. '],
#      'body': 3,
#      'body_description': 'Medium-bodied',
#      'acidity': 3,
#      'acidity_description': 'High',
#      'country': {'code': 'fr',
#       'name': 'France',
#       'native_name': 'France',
#       'seo_name': 'france',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 1308,
#       'users_count': 6776969,
#       'wines_count': 440256,
#       'wineries_count': 68417,
#       'most_used_grapes': [{'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 572334,
#         'parent_grape_id': None},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 604208,
#         'parent_grape_id': None},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 566719,
#         'parent_grape_id': None}]},
# ...
#         {'id': 105, 'name': 'cinnamon', 'count': 43},
#         {'id': 163, 'name': 'fig', 'count': 39},
#         {'id': 384, 'name': 'smoke', 'count': 38},
#         {'id': 117, 'name': 'coffee', 'count': 26},
#         {'id': 290, 'name': 'nutmeg', 'count': 22},
#         {'id': 112, 'name': 'clove', 'count': 17},
#         {'id': 83, 'name': 'cedar', 'count': 11},
#         {'id': 422, 'name': 'tobacco', 'count': 8},
#         {'id': 36, 'name': 'bitter almond', 'count': 4},
#         {'id': 118, 'name': 'cola', 'count': 2},
#         {'id': 149, 'name': 'dried leaves', 'count': 1},
#         {'id': 223, 'name': 'incense', 'count': 1},
#         {'id': 5, 'name': 'allspice', 'count': 1},
#         {'id': 280, 'name': 'mocha', 'count': 1}]},
#       {'group': 'citrus_fruit',
#        'stats': {'count': 1093, 'score': 152775},
#        'primary_keywords': [{'id': 266, 'name': 'marmalade', 'count': 383},
#         {'id': 298, 'name': 'orange', 'count': 376},
#         {'id': 106, 'name': 'citrus', 'count': 201},
#         {'id': 300, 'name': 'orange peel', 'count': 186},
#         {'id': 243, 'name': 'lemon', 'count': 142},
#         {'id': 252, 'name': 'lime', 'count': 52},
#         {'id': 411, 'name': 'tangerine', 'count': 50},
#         {'id': 302, 'name': 'orange zest', 'count': 48},
#         {'id': 190, 'name': 'grapefruit', 'count': 20},
#         {'id': 301, 'name': 'orange rind', 'count': 17},
#         {'id': 248, 'name': 'lemon zest', 'count': 12},
#         {'id': 246, 'name': 'lemon peel', 'count': 10},
#         {'id': 54, 'name': 'blood orange', 'count': 8},
#         {'id': 260, 'name': 'mandarin orange', 'count': 6},
#         {'id': 254, 'name': 'lime zest', 'count': 5},
#         {'id': 109, 'name': 'citrus zest', 'count': 2},
#         {'id': 236, 'name': 'key lime', 'count': 1},
#         {'id': 340, 'name': 'preserved lemon', 'count': 1},
#         {'id': 274, 'name': 'meyer lemon', 'count': 1}],
#        'secondary_keywords': [{'id': 244, 'name': 'lemon curd', 'count': 27}]},
#       {'group': 'microbio',
#        'stats': {'count': 816, 'score': 56834},
#        'primary_keywords': [{'id': 123, 'name': 'cream', 'count': 215},
#         {'id': 91, 'name': 'cheese', 'count': 122},
#         {'id': 295, 'name': 'oil', 'count': 62},
#         {'id': 23, 'name': 'banana', 'count': 29},
#         {'id': 244, 'name': 'lemon curd', 'count': 27},
#         {'id': 464, 'name': 'yogurt', 'count': 4},
#         {'id': 457, 'name': 'yeast', 'count': 2},
#         {'id': 129, 'name': 'curd', 'count': 2},
#         {'id': 92, 'name': 'cheesy', 'count': 1},
#         {'id': 419, 'name': 'toasted bread', 'count': 1},
#         {'id': 126, 'name': 'creme fraiche', 'count': 1}],
#        'secondary_keywords': [{'id': 6, 'name': 'almond', 'count': 183},
#         {'id': 424, 'name': 'toffee', 'count': 116},
#         {'id': 70, 'name': 'butter', 'count': 111},
#         {'id': 284, 'name': 'mushroom', 'count': 57},
#         {'id': 417, 'name': 'toast', 'count': 49},
#         {'id': 430, 'name': 'truffle', 'count': 21},
#         {'id': 239, 'name': 'lanolin', 'count': 4}]},
#       {'group': 'tropical_fruit',
#        'stats': {'count': 759, 'score': 101057},
#        'primary_keywords': [{'id': 329, 'name': 'pineapple', 'count': 439},
#         {'id': 428, 'name': 'tropical', 'count': 274},
#         {'id': 261, 'name': 'mango', 'count': 159},
#         {'id': 256, 'name': 'lychee', 'count': 39},
#         {'id': 306, 'name': 'passion fruit', 'count': 36},
#         {'id': 304, 'name': 'papaya', 'count': 20},
#         {'id': 210, 'name': 'guava', 'count': 14},
#         {'id': 208, 'name': 'grilled pineapple', 'count': 6},
#         {'id': 237, 'name': 'kiwi', 'count': 5},
#         {'id': 201, 'name': 'green mango', 'count': 3},
#         {'id': 227, 'name': 'jackfruit', 'count': 3},
#         {'id': 409, 'name': 'tamarind', 'count': 1},
#         {'id': 203, 'name': 'green papaya', 'count': 1},
#         {'id': 396, 'name': 'starfruit', 'count': 1}],
#        'secondary_keywords': [{'id': 23, 'name': 'banana', 'count': 29}]},
#       {'group': 'spices',
#        'stats': {'count': 613, 'score': 20333},
#        'primary_keywords': [{'id': 105, 'name': 'cinnamon', 'count': 43},
#         {'id': 449, 'name': 'white pepper', 'count': 26},
#         {'id': 277, 'name': 'mint', 'count': 22},
#         {'id': 320, 'name': 'pepper', 'count': 17},
#         {'id': 381, 'name': 'savory', 'count': 10},
#         {'id': 435, 'name': 'vanilla bean', 'count': 10},
#         {'id': 249, 'name': 'licorice', 'count': 8},
#         {'id': 75, 'name': 'candied ginger', 'count': 7},
#         {'id': 273, 'name': 'menthol', 'count': 6},
#         {'id': 286, 'name': 'musk', 'count': 5},
#         {'id': 182, 'name': 'gingerbread', 'count': 5},
#         {'id': 161, 'name': 'fennel', 'count': 5},
#         {'id': 7, 'name': 'anise', 'count': 4},
#         {'id': 26, 'name': 'bay leaf', 'count': 2},
#         {'id': 148, 'name': 'dried herbs', 'count': 2},
#         {'id': 30, 'name': 'bergamot', 'count': 1},
#         {'id': 159, 'name': 'eucalyptus', 'count': 1},
#         {'id': 416, 'name': 'thyme', 'count': 1}],
#        'secondary_keywords': [{'id': 434, 'name': 'vanilla', 'count': 397},
#         {'id': 181, 'name': 'ginger', 'count': 100},
#         {'id': 290, 'name': 'nutmeg', 'count': 22},
#         {'id': 112, 'name': 'clove', 'count': 17},
#         {'id': 138, 'name': 'dill', 'count': 6}]},
#       {'group': 'dried_fruit',
#        'stats': {'count': 517, 'score': 58166},
#        'primary_keywords': [{'id': 140, 'name': 'dried apricot', 'count': 274},
#         {'id': 347, 'name': 'raisin', 'count': 163},
#         {'id': 147, 'name': 'dried fruit', 'count': 53},
#         {'id': 163, 'name': 'fig', 'count': 39},
#         {'id': 341, 'name': 'prune', 'count': 25},
#         {'id': 184, 'name': 'golden raisin', 'count': 12},
#         {'id': 150, 'name': 'dried mango', 'count': 9},
#         {'id': 344, 'name': 'quince paste', 'count': 3},
#         {'id': 270, 'name': 'medjool date', 'count': 2},
#         {'id': 462, 'name': 'yellow raisin', 'count': 2},
#         {'id': 176, 'name': 'fruitcake', 'count': 1}],
#        'secondary_keywords': [{'id': 229, 'name': 'jam', 'count': 32}]},
#       {'group': 'floral',
#        'stats': {'count': 340, 'score': 37250},
#        'primary_keywords': [{'id': 221, 'name': 'honeysuckle', 'count': 199},
#         {'id': 2, 'name': 'acacia', 'count': 42},
#         {'id': 299, 'name': 'orange blossom', 'count': 26},
#         {'id': 230, 'name': 'jasmine', 'count': 25},
#         {'id': 322, 'name': 'perfume', 'count': 23},
#         {'id': 157, 'name': 'elderflower', 'count': 15},
#         {'id': 87, 'name': 'chamomile', 'count': 11},
#         {'id': 241, 'name': 'lavender', 'count': 9},
#         {'id': 251, 'name': 'lily', 'count': 5},
#         {'id': 10, 'name': 'apple blossom', 'count': 2},
#         {'id': 225, 'name': 'iris', 'count': 1},
#         {'id': 372, 'name': 'rose water', 'count': 1},
#         {'id': 215, 'name': 'hibiscus', 'count': 1},
#         {'id': 370, 'name': 'rose hip', 'count': 1},
#         {'id': 107, 'name': 'citrus blossom', 'count': 1},
#         {'id': 152, 'name': 'dried rose', 'count': 1},
#         {'id': 179, 'name': 'gardenia', 'count': 1},
#         {'id': 436, 'name': 'violet', 'count': 1},
#         {'id': 180, 'name': 'geranium', 'count': 1},
#         {'id': 319, 'name': 'peony', 'count': 1},
#         {'id': 250, 'name': 'lilac', 'count': 1},
#         {'id': 338, 'name': 'potpourri', 'count': 1},
#         {'id': 371, 'name': 'rose petal', 'count': 1}],
#        'secondary_keywords': [{'id': 381, 'name': 'savory', 'count': 10}]},
#       {'group': 'vegetal',
#        'stats': {'count': 238, 'score': 7163},
#        'primary_keywords': [{'id': 399, 'name': 'straw', 'count': 18},
#         {'id': 212, 'name': 'hay', 'count': 10},
#         {'id': 185, 'name': 'gooseberry', 'count': 7},
#         {'id': 193, 'name': 'grass', 'count': 7},
#         {'id': 36, 'name': 'bitter almond', 'count': 4},
#         {'id': 359, 'name': 'rhubarb', 'count': 4},
#         {'id': 194, 'name': 'green almond', 'count': 1},
#         {'id': 172, 'name': 'fresh-cut grass', 'count': 1},
#         {'id': 84, 'name': 'celery', 'count': 1}],
#        'secondary_keywords': [{'id': 6, 'name': 'almond', 'count': 183},
#         {'id': 381, 'name': 'savory', 'count': 10},
#         {'id': 149, 'name': 'dried leaves', 'count': 1}]},
#       {'group': 'black_fruit',
#        'stats': {'count': 89, 'score': 5951},
#        'primary_keywords': [{'id': 229, 'name': 'jam', 'count': 32},
#         {'id': 334, 'name': 'plum', 'count': 23},
#         {'id': 55, 'name': 'blueberry', 'count': 3},
#         {'id': 470, 'name': 'cassis', 'count': 2},
#         {'id': 41, 'name': 'black olive', 'count': 2},
#         {'id': 39, 'name': 'black fruit', 'count': 1},
#         {'id': 135, 'name': 'dark fruit', 'count': 1},
#         {'id': 52, 'name': 'blackcurrant', 'count': 1},
#         {'id': 402, 'name': 'sugarplum', 'count': 1},
#         {'id': 389, 'name': 'sour plum', 'count': 1}],
#        'secondary_keywords': [{'id': 341, 'name': 'prune', 'count': 25}]},
#       {'group': 'red_fruit',
#        'stats': {'count': 80, 'score': 5832},
#        'primary_keywords': [{'id': 400, 'name': 'strawberry', 'count': 16},
#         {'id': 348, 'name': 'raspberry', 'count': 15},
#         {'id': 93, 'name': 'cherry', 'count': 10},
#         {'id': 120, 'name': 'cotton candy', 'count': 3},
#         {'id': 440, 'name': 'watermelon', 'count': 2},
#         {'id': 357, 'name': 'red plum', 'count': 2},
#         {'id': 349, 'name': 'raspberry sauce', 'count': 1},
#         {'id': 171, 'name': 'fresh strawberry', 'count': 1},
#         {'id': 336, 'name': 'pomegranate', 'count': 1},
#         {'id': 446, 'name': 'white cherry', 'count': 1},
#         {'id': 263, 'name': 'maraschino cherry', 'count': 1}],
#        'secondary_keywords': [{'id': 229, 'name': 'jam', 'count': 32},
#         {'id': 176, 'name': 'fruitcake', 'count': 1}]}]},
#     'statistics': None,
#     'style': {'id': 195,
#      'seo_name': 'bordeaux-sauternes',
#      'regional_name': 'Bordeaux',
#      'varietal_name': 'Sauternes',
#      'name': 'Bordeaux Sauternes',
#      'background_image': None,
#      'image': None,
#      'description': None,
#      'blurb': 'Sweet white wine',
#      'interesting_facts': None,
#      'body': 4,
#      'body_description': 'Full-bodied',
#      'acidity': 3,
#      'acidity_description': 'High',
#      'country': {'code': 'fr',
#       'name': 'France',
#       'native_name': 'France',
#       'seo_name': 'france',
#       'currency': {'code': 'EUR',
#        'name': 'Euros',
#        'prefix': '€',
#        'suffix': None},
#       'regions_count': 1308,
#       'users_count': 6776969,
#       'wines_count': 440256,
#       'wineries_count': 68417,
#       'most_used_grapes': [{'id': 14,
#         'name': 'Pinot Noir',
#         'seo_name': 'pinot-noir',
#         'has_detailed_info': True,
#         'wines_count': 572334,
#         'parent_grape_id': None},
#        {'id': 5,
#         'name': 'Chardonnay',
#         'seo_name': 'chardonnay',
#         'has_detailed_info': True,
#         'wines_count': 604208,
#         'parent_grape_id': None},
#        {'id': 10,
#         'name': 'Merlot',
#         'seo_name': 'merlot',
#         'has_detailed_info': True,
#         'wines_count': 566719,
#         'parent_grape_id': None}]},
#      'wine_type_id': 7,
#      'food': [{'id': 37,
#        'name': 'Fruity desserts',
#        'weight': 0,
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/37_fruitydessert.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/37_fruitydessert_932x810.png'}},
#        'seo_name': None},
#       {'id': 38,
#        'name': 'Blue cheese',
#        'weight': 0,
#        'background_image': {'location': '//images.vivino.com/backgrounds/foods/38_bluecheese.png',
#         'variations': {'small': '//images.vivino.com/backgrounds/foods/thumbs/38_bluecheese_932x810.png'}},
#        'seo_name': None}],
#      'grapes': [{'id': 17,
#        'name': 'Sauvignon Blanc',
#        'seo_name': 'sauvignon-blanc',
#        'has_detailed_info': True,
#        'wines_count': 292440,
#        'parent_grape_id': None},
#       {'id': 18,
#        'name': 'Sémillon',
#        'seo_name': 'semillion',
#        'has_detailed_info': True,
#        'wines_count': 65710,
#        'parent_grape_id': None},
#       {'id': 89,
#        'name': 'Muscadelle',
#        'seo_name': 'muscadelle',
#        'has_detailed_info': False,
#        'wines_count': 10051,
#        'parent_grape_id': None}],
#      'region': {'id': 432,
#       'name': 'Sauternes',
#       'name_en': '',
#       'seo_name': 'sauternes',
#       'country': {'code': 'fr',
#        'name': 'France',
#        'native_name': 'France',
#        'seo_name': 'france',
#        'currency': {'code': 'EUR',
#         'name': 'Euros',
#         'prefix': '€',
#         'suffix': None},
#        'regions_count': 1308,
#        'users_count': 6776969,
#        'wines_count': 440256,
#        'wineries_count': 68417,
#        'most_used_grapes': [{'id': 14,
#          'name': 'Pinot Noir',
#          'seo_name': 'pinot-noir',
#          'has_detailed_info': True,
#          'wines_count': 572334,
#          'parent_grape_id': None},
#         {'id': 5,
#          'name': 'Chardonnay',
#          'seo_name': 'chardonnay',
#          'has_detailed_info': True,
#          'wines_count': 604208,
#          'parent_grape_id': None},
#         {'id': 10,
#          'name': 'Merlot',
#          'seo_name': 'merlot',
#          'has_detailed_info': True,
#          'wines_count': 566719,
#          'parent_grape_id': None}]},
#       'parent_id': 383,
#       'background_image': {'location': '//images.vivino.com/regions/backgrounds/NOjj4xPmSVeQew-vf1Tgdw.jpg',
#        'variations': {'large': '//thumbs.vivino.com/region_backgrounds/NOjj4xPmSVeQew-vf1Tgdw_1280x760.jpg',
#         'medium': '//thumbs.vivino.com/region_backgrounds/NOjj4xPmSVeQew-vf1Tgdw_600x356.jpg'}},
#       'class': {'typecast_map': {'background_image': {},
#         'class': {},
#         'location': {}}},
#       'statistics': {'wineries_count': 310,
#        'wines_count': 1533,
#        'sub_regions_count': 1,
#        'parent_regions_count': 1}},
#      'parent_style_id': 504,
#      'hidden': False,
#      'statistics': {'wines_count': 1519, 'aggregated_wines_count': 1519},
#      'vintage_mask': '1<',
#      'baseline_structure': {'acidity': 4.5,
#       'fizziness': None,
#       'intensity': 5.0,
#       'sweetness': 5.0,
#       'tannin': None}},
#     'has_valid_ratings': False},
#    'year': 2000,
#    'grapes': None,
#    'has_valid_ratings': True},
#   'price': {'id': 30573733,
#    'merchant_id': 34113,
#    'amount': 775696,
#    'discounted_from': 0,
#    'discount_percent': None,
#    'type': 'ppc',
#    'sku': '12771',
#    'url': 'https://rarecollection.eu/product/chateau-dyquem-2000-premier-cru/',
#    'visibility': 1,
#    'bottle_type_id': 1,
#    'currency': {'code': 'KRW',
#     'name': 'South Korean Won',
#     'prefix': '₩',
#     'suffix': None},
#    'xms': 0,
#    'xmphs': False,
#    'price_group_id': None,
#    'vfm_score': 0,
#    'vfm_category': {'id': 0,
#     'title': 'Value Unavailable',
#     'subtitle': 'We’re still gathering data to determine this wine’s value score',
#     'barometer_position': None},
#    'bottle_type': {'id': 1,
#     'name': 'Bottle (0.75l)',
#     'short_name': 'bottle',
#     'short_name_plural': 'bottles',
#     'volume_ml': 750}},
#   'prices': [{'id': 30573733,
#     'merchant_id': 34113,
#     'amount': 775696,
#     'discounted_from': 0,
#     'discount_percent': None,
#     'type': 'ppc',
#     'sku': '12771',
#     'url': 'https://rarecollection.eu/product/chateau-dyquem-2000-premier-cru/',
#     'visibility': 1,
#     'bottle_type_id': 1,
#     'currency': {'code': 'KRW',
#      'name': 'South Korean Won',
#      'prefix': '₩',
#      'suffix': None},
#     'xms': 0,
#     'xmphs': False,
#     'price_group_id': None,
#     'vfm_score': 0,
#     'vfm_category': {'id': 0,
#      'title': 'Value Unavailable',
#      'subtitle': 'We’re still gathering data to determine this wine’s value score',
#      'barometer_position': None},
#     'bottle_type': {'id': 1,
#      'name': 'Bottle (0.75l)',
#      'short_name': 'bottle',
#      'short_name_plural': 'bottles',
#      'volume_ml': 750}}]}]

# %%
column_names=["vintage_id", "vintage_name", "vintage_year", "vintage_price", "vintage_ratings_average", "vintage_ratings_count", "vintage_wine_id", "vintage_wine_name",  "vintage_winery", "vintage_country", "vintage_region", "vintage_wine_type_id", "acidity", "fizziness", "intensity", "sweetness", "tannin", "flavor", "foods" ]

# %%
import numpy as np

# %%
# with open('response_data.json', 'r', encoding='utf-8') as file:
#     data = json.load(file)
matches = r.json()['explore_vintage']['matches']

# None 여부 검사 
# foods = matches[0]['vintage']['wine']['style']['food']
results = []
for match in matches:
    if match['vintage'] is None:
        print('vintage가 존재하지 않습니다.')
    else:
        vintage_id = match['vintage']['id']
        vintage_name = match['vintage']['name']
        vintage_year = match["vintage"]["year"]
        vintage_price = match["prices"][0]["amount"]
        vintage_ratings_average = match["vintage"]["statistics"]["ratings_average"]
        vintage_ratings_count = match["vintage"]["statistics"]["ratings_count"]
        
        if match['vintage']['wine'] is None:
            print('wine이 존재하지 않습니다.')
        else:
            vintage_wine_id = match["vintage"]["wine"]["id"]
            vintage_wine_name = f'{match["vintage"]["wine"]["name"]} {match["vintage"]["year"]}'
            vintage_winery = match["vintage"]["wine"]["winery"]["name"]
            vintage_country = match['vintage']['wine']['region']['country']['name']
            vintage_region = match['vintage']['wine']['region']['name']
            vintage_wine_type_id = match['vintage']['wine']['type_id']
            
            taste = match['vintage']['wine']['taste']
            acidity = np.nan
            fizziness = np.nan
            intensity = np.nan
            sweetness = np.nan
            tannin = np.nan
            flavor = np.nan
            
            if taste is None:
                pass
            else:
                structure = taste['structure']
                if structure is None:
                    pass
                else:
                    acidity = structure['acidity']
                    fizziness = structure['fizziness']
                    intensity = structure['intensity']
                    sweetness = structure['sweetness']
                    tannin = structure['tannin']
                    if acidity is None:
                        pass
                    if fizziness is None:
                        pass
                    if intensity is None:
                        pass
                    if sweetness is None:
                        pass
                    if tannin is None:
                        pass
                flavor_list = taste['flavor']
                if flavor_list is None:
                    pass
                else:
                    flavor = flavor_list[0]['group']
                    if flavor is None:
                        pass

            style = match['vintage']['wine']['style']
            foods = [] # 초기값
            if style is None:
                pass
            else:
                foods_list = style['food']
                if foods_list is None:
                    pass
                else:
                    for food in foods_list:
                        foods.append(food['name'])
                
            results.append((vintage_id, vintage_name, vintage_year, vintage_price, vintage_ratings_average, vintage_ratings_count, vintage_wine_id, vintage_wine_name,  vintage_winery, vintage_country, vintage_region, vintage_wine_type_id, acidity, fizziness, intensity, sweetness, tannin, flavor, foods))

df = pd.DataFrame(results, columns=column_names)

# %%
df.shape
# Out:
# (25, 19)

# %%
df.head()
# Out:
#    vintage_id                                       vintage_name  \
# 0   177404982                     Carl Loewen 1896 Riesling 2023
# 1     2184215                        Château Pétrus Pomerol 1960
# 2     1510217  Château Haut-Brion Pessac-Léognan (Premier Gra...
# 3     2611979  Château Latour Grand Vin Pauillac (Premier Gra...
# 4     1889890                        Château Pétrus Pomerol 1990
#
#    vintage_year  vintage_price  vintage_ratings_average  \
# 0          2023          82045                      5.0
# 1          1960        6209294                      4.9
# 2          1989        3244496                      4.8
# 3          1982        2759686                      4.8
# 4          1990        6861922                      4.8
#
#    vintage_ratings_count  vintage_wine_id  \
# 0                    115          1945087
# 1                     65          1166837
# 2                   1538          1152755
# 3                   1445          1655970
# 4                   1245          1166837
#
#                                    vintage_wine_name      vintage_winery  \
# 0                                 1896 Riesling 2023         Carl Loewen
# 1                                       Pomerol 1960      Château Pétrus
# 2     Pessac-Léognan (Premier Grand Cru Classé) 1989  Château Haut-Brion
# 3  Grand Vin Pauillac (Premier Grand Cru Classé) ...      Château Latour
# 4                                       Pomerol 1990      Château Pétrus
#
#   vintage_country  vintage_region  vintage_wine_type_id  acidity  fizziness  \
# 0         Germany           Mosel                     2     4.61        NaN
# 1          France         Pomerol                     1     3.37        NaN
# 2          France  Pessac-Léognan                     1     4.22        NaN
# 3          France        Pauillac                     1     4.12        NaN
# 4          France         Pomerol                     1     3.37        NaN
#
#    intensity  sweetness  tannin      flavor  \
# 0       3.32       2.05     NaN  tree_fruit
# 1       4.13       1.97    3.45         oak
# 2       4.08       1.67    4.23         oak
# 3       4.12       1.68    4.13         oak
# 4       4.13       1.97    3.45         oak
#
#                                                foods
# 0  [Pork, Shellfish, Spicy food, Poultry, Cured M...
# 1        [Beef, Lamb, Game (deer, venison), Poultry]
# 2        [Beef, Lamb, Game (deer, venison), Poultry]
# 3        [Beef, Lamb, Game (deer, venison), Poultry]
# 4        [Beef, Lamb, Game (deer, venison), Poultry]

# %%
# import numpy as np
# 
# all_results = []
# for i in range(int(n_matches / 25)):
#     # 각 페이지당 25개의 result 존재, 페이지 넘길 때마다 알림 호출
#     payload['page'] = i + 1
#     print(f'Requesting data from page: {payload["page"]}')
# 
#     r = requests.get('https://www.vivino.com/api/explore/explore?',
#                  params=payload, headers=headers)
#     results = [
#         (
#             t["vintage"]["year"],
#             t["vintage"]["wine"]["id"],
#             f'{t["vintage"]["wine"]["name"]} {t["vintage"]["year"]}',
#             t["vintage"]["statistics"]["ratings_average"],
#             t["vintage"]["statistics"]["ratings_count"],
#             t["prices"][0]["amount"],
#             t["vintage"]["wine"]["winery"]["name"],
#             t['vintage']['wine']['region']['country']['name'],
#             t['vintage']['wine']['region']['name'],
#             t['vintage']['wine']['type_id'],
#             # Safely accessing and returning np.nan if any part is None
#             (t.get("vintage", {}).get("wine", {}).get("taste", {}).get("structure", {}).get('acidity', np.nan) 
#              if t.get("vintage", {}).get("wine", {}).get("taste", {}).get("structure") is not None else np.nan),           
#             (t.get("vintage", {}).get("wine", {}).get("taste", {}).get("structure", {}).get('fizziness', np.nan) 
#              if t.get("vintage", {}).get("wine", {}).get("taste", {}).get("structure") is not None else np.nan),            
#             (t.get("vintage", {}).get("wine", {}).get("taste", {}).get("structure", {}).get('intensity', np.nan) 
#              if t.get("vintage", {}).get("wine", {}).get("taste", {}).get("structure") is not None else np.nan),            
#             (t.get("vintage", {}).get("wine", {}).get("taste", {}).get("structure", {}).get('sweetness', np.nan) 
#              if t.get("vintage", {}).get("wine", {}).get("taste", {}).get("structure") is not None else np.nan),            
#             (t.get("vintage", {}).get("wine", {}).get("taste", {}).get("structure", {}).get('tannin', np.nan) 
#              if t.get("vintage", {}).get("wine", {}).get("taste", {}).get("structure") is not None else np.nan),           
#             t.get("vintage", {}).get("wine", {}).get("taste", {}).get("flavor", [{}])[0].get("group", np.nan) 
#             if t.get("vintage", {}).get("wine", {}).get("taste", {}).get("flavor") else np.nan,
#             
#         )
#         for t in r.json()["explore_vintage"]["matches"] 
#     ]   
#     
#     all_results.extend(results)
# 
# df = pd.DataFrame(all_results, columns=column_names)

# %%
df.head()
# Out:
#    Year  Wine_ID                                    Wine_name(year)  \
# 0  2023  1945087                                 1896 Riesling 2023
# 1  1960  1166837                                       Pomerol 1960
# 2  1989  1152755     Pessac-Léognan (Premier Grand Cru Classé) 1989
# 3  1982  1655970  Grand Vin Pauillac (Premier Grand Cru Classé) ...
# 4  1990  1166837                                       Pomerol 1990
#
#    Ratings_average  Ratings_count    price              Winery  Country  \
# 0              5.0            115    82045         Carl Loewen  Germany
# 1              4.9             65  6209294      Château Pétrus   France
# 2              4.8           1538  3244496  Château Haut-Brion   France
# 3              4.8           1445  2759686      Château Latour   France
# 4              4.8           1245  6861922      Château Pétrus   France
#
#            Region  Wine_type_id  acidity  fizziness  intensity  sweetness  \
# 0           Mosel             2     4.61        NaN       3.32       2.05
# 1         Pomerol             1     3.37        NaN       4.13       1.97
# 2  Pessac-Léognan             1     4.22        NaN       4.08       1.67
# 3        Pauillac             1     4.12        NaN       4.12       1.68
# 4         Pomerol             1     3.37        NaN       4.13       1.97
#
#    tannin      flavor food
# 0     NaN  tree_fruit   []
# 1    3.45         oak   []
# 2    4.23         oak   []
# 3    4.13         oak   []
# 4    3.45         oak   []

# %%
df['Wine_type_id'].unique()
df['food'].value_counts()
# Out:
# food
# []    3625
# Name: count, dtype: int64

# %%
df.to_csv(r"C:\SD card\Documents\Data Analytics\Vivino Webscraper\vivino.csv", index=False)
